# %% [markdown]
# #### Designing a time-stepper model for Allen Cahn - Multiparameter

# %%
import jax.numpy as jnp
import numpy.random as npr
from jax import jit, grad, vmap
from jax.example_libraries.optimizers import adam
from jax import value_and_grad
from functools import partial
from jax import jacfwd, jacrev
import jax.nn as jnn
import math
from jax import random
import jax
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from flax import linen as nn
import sklearn.metrics

import argparse
import os
import time
from termcolor import colored
from scipy.io import loadmat
import scipy.io as io
import pickle

import sys
sys.path.append("../..")

import matplotlib
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 9})
import seaborn as sns
sns.set_style("white")
sns.set_style("ticks")

import warnings
warnings.filterwarnings("ignore")

# Check where gpu is enable or not
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# cpu

# %%
cluster = False
save = True

# %%
if cluster == True:
    parser = argparse.ArgumentParser()
    parser.add_argument('-seed', dest='seed', type=int, default=0, help='Seed number.')
    args = parser.parse_args()

    # Print all the arguments
    for arg in vars(args):
        print(f'{arg}: {getattr(args, arg)}')

    seed = args.seed

if cluster == False:
    seed = 0 # Seed number.

if save == True:
    resultdir = os.path.join(os.getcwd(), 'Results')
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

if save == True and cluster == True:
    orig_stdout = sys.stdout
    q = open(os.path.join(resultdir, 'outputs.txt'), 'w')
    sys.stdout = q
    print ("------START------")

print('seed = '+str(seed))
# Out:
# seed = 0

# %%
np.random.seed(seed)
key = 1234 #random.PRNGKey(seed)

# %%
# Load the data
data = loadmat('../data/multiparameter/data_022_070_AC_chebfun_more_new_aligned_healing_shorter2.mat') # Load the .mat file
# print(data)
print(data['Utrain_branch'].shape) # Inputs to branch in training
print(data['Utest_branch'].shape) # Inputs to branch in testing
print(data['Vtest_out'].shape) # Output for test samples

# Convert NumPy arrays to PyTorch tensors
inputs_train = jnp.array(data['Utrain_branch']).T
outputs_train = jnp.array(data['Vtrain_out']).T
inputs_test = jnp.array(data['Utest_branch']).T
outputs_test = jnp.array(data['Vtest_out']).T
grid = jnp.array(data['Ytrain_trunk'])
#print("grid:", grid)

# Check the shapes of the subsets
print("Shape of inputs_train:", inputs_train.shape)
print("Shape of inputs_test:", inputs_test.shape)
print("Shape of outputs_train:", outputs_train.shape)
print("Shape of outputs_test:", outputs_test.shape)
print('#'*100)
# Out:
# (101, 22259)
# (101, 5565)
# (100, 5565)
# Shape of inputs_train: (22259, 101)
# Shape of inputs_test: (5565, 101)
# Shape of outputs_train: (22259, 100)
# Shape of outputs_test: (5565, 100)
# ####################################################################################################

# %%
# Initialize the Glorot (Xavier) normal distribution for weight initialization
initializer = jax.nn.initializers.glorot_normal()

def init_glorot_params(layer_sizes, key = random.PRNGKey(seed)):
    """
    Initialize the parameters of the neural network using Glorot (Xavier) initialization.

    Args:
    layer_sizes (list): List of integers representing the size of each layer.
    key (PRNGKey): Random number generator key for reproducibility.

    Returns:
    list: List of tuples, each containing weights and biases for a layer.
    """
    return [(initializer(key, (m, n), jnp.float32), jnp.zeros(n))
            for m, n, in zip(layer_sizes[:-1], layer_sizes[1:])]

def BranchNet(params, x):
    """
    Implement the branch network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (array): Input to the branch network.

    Returns:
    array: Output of the branch network.
    """
    def single_forward(params, x):
        for w, b in params:
            outputs = jnp.dot(x, w) + b
            x = jnn.silu(outputs)
        return outputs

    return vmap(partial(single_forward, params))(x)

def TrunkNet(params, x):
    """
    Implement the trunk network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (float): First input to the trunk network.
    t (float): Second input to the trunk network.

    Returns:
    array: Output of the trunk network.
    """
    inputs = jnp.array(x)
    for w, b in params:
        outputs = jnp.dot(x, w) + b
        x = jnn.silu(outputs)
    return outputs

@jit
def DeepONet(params, branch_inputs, trunk_inputs):
    """
    Implement the complete DeepONet architecture.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.

    Returns:
    array: Output of the DeepONet.
    """
    params_branch, params_trunk = params
    branch_outputs = lambda x: BranchNet(params_branch, x)
    b_out = branch_outputs(branch_inputs)
    trunk_output = lambda y: TrunkNet(params_trunk, y)
    t_out = trunk_output(trunk_inputs)
    results = jnp.einsum('ik, lk -> il',b_out, t_out)
    return results

# network parameters.
p = 300 # Number of output neurons in both the branch and trunk net outputs.
nx = 101
input_neurons_branch = nx # m
input_neurons_trunk = 1

layer_sizes_b = [input_neurons_branch] + [100]*6 + [p]
layer_sizes_t = [input_neurons_trunk] + [100]*6 + [p]

params_branch = init_glorot_params(layer_sizes=layer_sizes_b)
params_trunk = init_glorot_params(layer_sizes=layer_sizes_t)

params= (params_branch, params_trunk)

def objective(params, branch_inputs, trunk_inputs, target_values):
    """
    Define the objective function (loss function) for training.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values to compare against.

    Returns:
    float: Mean squared error loss.
    """
    predictions = DeepONet(params, branch_inputs, trunk_inputs)
    loss_mse = jnp.mean((predictions - target_values)**2)
    return loss_mse


# Adam optimizer
@jit
def resnet_update(params, branch_input, trunk_inputs, target_values, opt_state):
    """
    Compute the gradient for a batch and update the parameters.

    Args:
    params (tuple): Current network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values.
    opt_state: Current state of the optimizer.

    Returns:
    tuple: Updated parameters, updated optimizer state, and current loss value.
    """
    value, grads = value_and_grad(objective)(params, branch_input, trunk_inputs, target_values)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, value

# Initialize the Adam optimizer
opt_init, opt_update, get_params = adam(step_size=1e-3, b1=0.9, b2=0.999, eps=1e-08)
opt_state = opt_init(params)

bs = 3000 #batch size
iteration_list, loss_list, test_loss_list = [], [], []
iteration = 0

n_epochs = 100000
num_samples = len(inputs_train)

# test input preparation
branch_inputs_test = inputs_test
targets = outputs_test

# %%
def save_model_params(params, resultdir, filename='model_params.pkl'):
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

    save_path = os.path.join(resultdir, filename)
    with open(save_path, 'wb') as f:
        pickle.dump(params, f)

def load_model_params(resultdir, filename='model_params.pkl'):
    load_path = os.path.join(resultdir, filename)
    with open(load_path, 'rb') as f:
        params = pickle.load(f)
    return params

# Saving
if save:
    save_model_params(params, resultdir)

# Loading (uncomment when needed)
# model_params = load_model_params(resultdir)

# %%
## Training of DeepONet
start = time.time() # start time of training
best_test_mse = float('inf')  # Initialize with infinity

# Save initial model at 0th iteration
save_model_params(params, resultdir, filename='model_params_best.pkl')
print("Saved initial model at iteration 0")

for iteration in range(n_epochs):
    indices = jax.random.permutation(jax.random.PRNGKey(0), num_samples)
    batch_index = indices[0:bs]
    inputs_train_shuffled = inputs_train[batch_index]
    outputs_train_shuffled = outputs_train[batch_index]
    target_values = outputs_train_shuffled
    branch_inputs = inputs_train_shuffled
    trunk_inputs = grid
    params, opt_state, value = resnet_update(params, branch_inputs, trunk_inputs, target_values, opt_state)

    if iteration % 1000 == 0:
        params_branch, params_trunk = params
        predictions = DeepONet(params, branch_inputs, trunk_inputs)
        test_mse = jnp.mean((predictions - target_values)**2)

        # Compare current test error with the best so far
        if test_mse < best_test_mse:
            best_test_mse = test_mse
            # Save the model as it's the best so far
            save_model_params(params, resultdir, filename='model_params_best.pkl')
            print(f"New best model saved at iteration {iteration} with test MSE: {test_mse:.7f}")

        finish = time.time() - start
        print(f"Iteration: {iteration:3d}, Train loss: {objective(params, branch_inputs, trunk_inputs, target_values):.7f}, Test loss: {test_mse:.7f}, Best test loss: {best_test_mse:.7f}, Time: {finish:.2f}")

    iteration_list.append(iteration)
    loss_list.append(objective(params, branch_inputs, trunk_inputs, target_values))
    test_loss_list.append(test_mse)

if save:
    np.save(os.path.join(resultdir, 'iteration_list.npy'), np.asarray(iteration_list))
    np.save(os.path.join(resultdir, 'loss_list.npy'), np.asarray(loss_list))
    np.save(os.path.join(resultdir, 'test_loss_list.npy'), np.asarray(test_loss_list))

# Plotting code remains the same
plt.figure()
plt.plot(iteration_list, loss_list, 'g', label='Training loss')
plt.plot(iteration_list, test_loss_list, '-b', label='Test loss')
plt.yscale("log")
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

if save:
    plt.savefig(os.path.join(resultdir, 'loss_plot.pdf'))

# end timer
finish = time.time() - start
print("Time (sec) to complete:\n" + str(finish))
# Out:
# Saved initial model at iteration 0
# New best model saved at iteration 0 with test MSE: 0.2552185
# Iteration:   0, Train loss: 0.2552185, Test loss: 0.2552185, Best test loss: 0.2552185, Time: 0.97
# New best model saved at iteration 1000 with test MSE: 0.0008754
# Iteration: 1000, Train loss: 0.0008754, Test loss: 0.0008754, Best test loss: 0.0008754, Time: 26.63
# New best model saved at iteration 2000 with test MSE: 0.0007036
# Iteration: 2000, Train loss: 0.0007036, Test loss: 0.0007036, Best test loss: 0.0007036, Time: 52.76
# New best model saved at iteration 3000 with test MSE: 0.0004082
# Iteration: 3000, Train loss: 0.0004082, Test loss: 0.0004082, Best test loss: 0.0004082, Time: 78.53
# New best model saved at iteration 4000 with test MSE: 0.0003561
# Iteration: 4000, Train loss: 0.0003561, Test loss: 0.0003561, Best test loss: 0.0003561, Time: 104.26
# New best model saved at iteration 5000 with test MSE: 0.0003441
# Iteration: 5000, Train loss: 0.0003441, Test loss: 0.0003441, Best test loss: 0.0003441, Time: 130.23
# New best model saved at iteration 6000 with test MSE: 0.0001815
# Iteration: 6000, Train loss: 0.0001815, Test loss: 0.0001815, Best test loss: 0.0001815, Time: 156.18
# New best model saved at iteration 7000 with test MSE: 0.0001225
# Iteration: 7000, Train loss: 0.0001225, Test loss: 0.0001225, Best test loss: 0.0001225, Time: 182.32
# New best model saved at iteration 8000 with test MSE: 0.0000541
# Iteration: 8000, Train loss: 0.0000541, Test loss: 0.0000541, Best test loss: 0.0000541, Time: 207.81
# Iteration: 9000, Train loss: 0.0000573, Test loss: 0.0000573, Best test loss: 0.0000541, Time: 233.35
# New best model saved at iteration 10000 with test MSE: 0.0000374
# Iteration: 10000, Train loss: 0.0000374, Test loss: 0.0000374, Best test loss: 0.0000374, Time: 260.02
# Iteration: 11000, Train loss: 0.0000639, Test loss: 0.0000639, Best test loss: 0.0000374, Time: 285.53
# New best model saved at iteration 12000 with test MSE: 0.0000285
# Iteration: 12000, Train loss: 0.0000285, Test loss: 0.0000285, Best test loss: 0.0000285, Time: 310.99
# Iteration: 13000, Train loss: 0.0002731, Test loss: 0.0002731, Best test loss: 0.0000285, Time: 336.52
# Iteration: 14000, Train loss: 0.0000478, Test loss: 0.0000478, Best test loss: 0.0000285, Time: 362.11
# Iteration: 15000, Train loss: 0.0000316, Test loss: 0.0000316, Best test loss: 0.0000285, Time: 387.82
# New best model saved at iteration 16000 with test MSE: 0.0000284
# Iteration: 16000, Train loss: 0.0000284, Test loss: 0.0000284, Best test loss: 0.0000284, Time: 413.65
# New best model saved at iteration 17000 with test MSE: 0.0000275
# Iteration: 17000, Train loss: 0.0000275, Test loss: 0.0000275, Best test loss: 0.0000275, Time: 439.61
# New best model saved at iteration 18000 with test MSE: 0.0000270
# Iteration: 18000, Train loss: 0.0000270, Test loss: 0.0000270, Best test loss: 0.0000270, Time: 465.46
# Iteration: 19000, Train loss: 0.0000270, Test loss: 0.0000270, Best test loss: 0.0000270, Time: 491.57
# Iteration: 20000, Train loss: 0.0000270, Test loss: 0.0000270, Best test loss: 0.0000270, Time: 517.41
# New best model saved at iteration 21000 with test MSE: 0.0000236
# Iteration: 21000, Train loss: 0.0000236, Test loss: 0.0000236, Best test loss: 0.0000236, Time: 543.28
# Iteration: 22000, Train loss: 0.0000361, Test loss: 0.0000361, Best test loss: 0.0000236, Time: 569.07
# New best model saved at iteration 23000 with test MSE: 0.0000182
# Iteration: 23000, Train loss: 0.0000182, Test loss: 0.0000182, Best test loss: 0.0000182, Time: 594.95
# Iteration: 24000, Train loss: 0.0000372, Test loss: 0.0000372, Best test loss: 0.0000182, Time: 620.70
# New best model saved at iteration 25000 with test MSE: 0.0000106
# Iteration: 25000, Train loss: 0.0000106, Test loss: 0.0000106, Best test loss: 0.0000106, Time: 646.61
# Iteration: 26000, Train loss: 0.0000183, Test loss: 0.0000183, Best test loss: 0.0000106, Time: 672.42
# Iteration: 27000, Train loss: 0.0000115, Test loss: 0.0000115, Best test loss: 0.0000106, Time: 698.22
# Iteration: 28000, Train loss: 0.0000124, Test loss: 0.0000124, Best test loss: 0.0000106, Time: 723.98
# New best model saved at iteration 29000 with test MSE: 0.0000064
# Iteration: 29000, Train loss: 0.0000064, Test loss: 0.0000064, Best test loss: 0.0000064, Time: 749.92
# Iteration: 30000, Train loss: 0.0000132, Test loss: 0.0000132, Best test loss: 0.0000064, Time: 775.96
# Iteration: 31000, Train loss: 0.0000468, Test loss: 0.0000468, Best test loss: 0.0000064, Time: 802.17
# Iteration: 32000, Train loss: 0.0000211, Test loss: 0.0000211, Best test loss: 0.0000064, Time: 827.76
# Iteration: 33000, Train loss: 0.0000256, Test loss: 0.0000256, Best test loss: 0.0000064, Time: 853.21
# Iteration: 34000, Train loss: 0.0000114, Test loss: 0.0000114, Best test loss: 0.0000064, Time: 879.71
# Iteration: 35000, Train loss: 0.0000068, Test loss: 0.0000068, Best test loss: 0.0000064, Time: 907.30
# New best model saved at iteration 36000 with test MSE: 0.0000060
# Iteration: 36000, Train loss: 0.0000060, Test loss: 0.0000060, Best test loss: 0.0000060, Time: 936.56
# Iteration: 37000, Train loss: 0.0000083, Test loss: 0.0000083, Best test loss: 0.0000060, Time: 965.70
# Iteration: 38000, Train loss: 0.0000109, Test loss: 0.0000109, Best test loss: 0.0000060, Time: 993.35
# New best model saved at iteration 39000 with test MSE: 0.0000060
# Iteration: 39000, Train loss: 0.0000060, Test loss: 0.0000060, Best test loss: 0.0000060, Time: 1019.32
# New best model saved at iteration 40000 with test MSE: 0.0000056
# Iteration: 40000, Train loss: 0.0000056, Test loss: 0.0000056, Best test loss: 0.0000056, Time: 1044.75
# Iteration: 41000, Train loss: 0.0000086, Test loss: 0.0000086, Best test loss: 0.0000056, Time: 1070.23
# New best model saved at iteration 42000 with test MSE: 0.0000055
# Iteration: 42000, Train loss: 0.0000055, Test loss: 0.0000055, Best test loss: 0.0000055, Time: 1095.77
# Iteration: 43000, Train loss: 0.0000199, Test loss: 0.0000199, Best test loss: 0.0000055, Time: 1121.22
# Iteration: 44000, Train loss: 0.0000079, Test loss: 0.0000079, Best test loss: 0.0000055, Time: 1146.69
# Iteration: 45000, Train loss: 0.0000059, Test loss: 0.0000059, Best test loss: 0.0000055, Time: 1172.19
# New best model saved at iteration 46000 with test MSE: 0.0000052
# Iteration: 46000, Train loss: 0.0000052, Test loss: 0.0000052, Best test loss: 0.0000052, Time: 1197.84
# New best model saved at iteration 47000 with test MSE: 0.0000037
# Iteration: 47000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000037, Time: 1223.39
# New best model saved at iteration 48000 with test MSE: 0.0000030
# Iteration: 48000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000030, Time: 1249.21
# Iteration: 49000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000030, Time: 1274.88
# Iteration: 50000, Train loss: 0.0000105, Test loss: 0.0000105, Best test loss: 0.0000030, Time: 1300.42
# Iteration: 51000, Train loss: 0.0000878, Test loss: 0.0000878, Best test loss: 0.0000030, Time: 1326.01
# Iteration: 52000, Train loss: 0.0000270, Test loss: 0.0000270, Best test loss: 0.0000030, Time: 1351.61
# Iteration: 53000, Train loss: 0.0000131, Test loss: 0.0000131, Best test loss: 0.0000030, Time: 1377.22
# Iteration: 54000, Train loss: 0.0000088, Test loss: 0.0000088, Best test loss: 0.0000030, Time: 1402.75
# Iteration: 55000, Train loss: 0.0000060, Test loss: 0.0000060, Best test loss: 0.0000030, Time: 1428.33
# Iteration: 56000, Train loss: 0.0000051, Test loss: 0.0000051, Best test loss: 0.0000030, Time: 1454.12
# Iteration: 57000, Train loss: 0.0000121, Test loss: 0.0000121, Best test loss: 0.0000030, Time: 1480.70
# Iteration: 58000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000030, Time: 1506.17
# Iteration: 59000, Train loss: 0.0000044, Test loss: 0.0000044, Best test loss: 0.0000030, Time: 1531.93
# Iteration: 60000, Train loss: 0.0000044, Test loss: 0.0000044, Best test loss: 0.0000030, Time: 1557.47
# Iteration: 61000, Train loss: 0.0000059, Test loss: 0.0000059, Best test loss: 0.0000030, Time: 1583.13
# Iteration: 62000, Train loss: 0.0000082, Test loss: 0.0000082, Best test loss: 0.0000030, Time: 1608.82
# Iteration: 63000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000030, Time: 1634.45
# Iteration: 64000, Train loss: 0.0000113, Test loss: 0.0000113, Best test loss: 0.0000030, Time: 1659.98
# New best model saved at iteration 65000 with test MSE: 0.0000025
# Iteration: 65000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000025, Time: 1685.78
# Iteration: 66000, Train loss: 0.0000075, Test loss: 0.0000075, Best test loss: 0.0000025, Time: 1711.33
# New best model saved at iteration 67000 with test MSE: 0.0000013
# Iteration: 67000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000013, Time: 1736.87
# Iteration: 68000, Train loss: 0.0000053, Test loss: 0.0000053, Best test loss: 0.0000013, Time: 1762.72
# Iteration: 69000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000013, Time: 1788.33
# Iteration: 70000, Train loss: 0.0000064, Test loss: 0.0000064, Best test loss: 0.0000013, Time: 1813.92
# Iteration: 71000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000013, Time: 1839.78
# Iteration: 72000, Train loss: 0.0000036, Test loss: 0.0000036, Best test loss: 0.0000013, Time: 1865.44
# Iteration: 73000, Train loss: 0.0000138, Test loss: 0.0000138, Best test loss: 0.0000013, Time: 1891.01
# Iteration: 74000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000013, Time: 1916.59
# Iteration: 75000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000013, Time: 1942.15
# Iteration: 76000, Train loss: 0.0000032, Test loss: 0.0000032, Best test loss: 0.0000013, Time: 1967.77
# Iteration: 77000, Train loss: 0.0000437, Test loss: 0.0000437, Best test loss: 0.0000013, Time: 1993.42
# Iteration: 78000, Train loss: 0.0000181, Test loss: 0.0000181, Best test loss: 0.0000013, Time: 2019.21
# Iteration: 79000, Train loss: 0.0000091, Test loss: 0.0000091, Best test loss: 0.0000013, Time: 2044.99
# Iteration: 80000, Train loss: 0.0000125, Test loss: 0.0000125, Best test loss: 0.0000013, Time: 2070.88
# Iteration: 81000, Train loss: 0.0000036, Test loss: 0.0000036, Best test loss: 0.0000013, Time: 2097.65
# Iteration: 82000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000013, Time: 2123.27
# Iteration: 83000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000013, Time: 2149.01
# Iteration: 84000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000013, Time: 2174.43
# Iteration: 85000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000013, Time: 2200.18
# Iteration: 86000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000013, Time: 2225.78
# Iteration: 87000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000013, Time: 2251.32
# Iteration: 88000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000013, Time: 2277.27
# Iteration: 89000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000013, Time: 2303.20
# Iteration: 90000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000013, Time: 2328.60
# Iteration: 91000, Train loss: 0.0000040, Test loss: 0.0000040, Best test loss: 0.0000013, Time: 2353.99
# Iteration: 92000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000013, Time: 2379.57
# Iteration: 93000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000013, Time: 2405.11
# Iteration: 94000, Train loss: 0.0000100, Test loss: 0.0000100, Best test loss: 0.0000013, Time: 2430.69
# Iteration: 95000, Train loss: 0.0000052, Test loss: 0.0000052, Best test loss: 0.0000013, Time: 2456.16
# Iteration: 96000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000013, Time: 2481.61
# Iteration: 97000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000013, Time: 2507.10
# Iteration: 98000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000013, Time: 2532.86
# Iteration: 99000, Train loss: 0.0000092, Test loss: 0.0000092, Best test loss: 0.0000013, Time: 2558.67
# Time (sec) to complete:
# 2585.6226949691772

# %%
# params_branch, params_trunk = params
# Load the best model parameters
best_params = load_model_params(resultdir, filename='model_params_best.pkl')
print("Loaded best model parameters")

# Predictions
mse_list = []

branch_inputs = inputs_test
trunk_inputs = grid
prediction = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval) 

save_dict = {'u_test': inputs_test.T, 'v_pred': prediction.T,\
             'v_target': outputs_test.T}

io.savemat(resultdir+'/pred.mat', save_dict)

for i in range(inputs_test.shape[0]):

    branch_inputs = inputs_test[i].reshape(1, nx) 
    trunk_inputs = grid # (neval, 1) 

    prediction_i = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval)
    target_i = outputs_test[i]

    mse_i = np.mean((prediction_i - target_i)**2)
    mse_list.append(mse_i.item())

    if i % 1000 == 0:
        print(colored('TEST SAMPLE '+str(i+1), 'red'))

        r2score = metrics.r2_score(target_i.flatten(), prediction_i.flatten())
        relerror = np.linalg.norm(target_i- prediction_i) / np.linalg.norm(target_i)
        r2score = float('%.4f'%r2score)
        relerror = float('%.4f'%relerror)
        print('Rel. L2 Error = '+str(relerror)+', R2 score = '+str(r2score))

        fig = plt.figure(figsize=(15, 4))

        # Adjust subplot parameters for better spacing
        plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.3)

        # Input plot
        ax = fig.add_subplot(1, 3, 1)
        plt.plot(inputs_test[i,0:-1])
        plt.title('Input', fontsize=14)

        # Output plot
        ax = fig.add_subplot(1, 3, 2)
        target = target_i.reshape(grid.shape[0])
        prediction = prediction_i.reshape(grid.shape[0])
        plt.plot(target, color='blue', linewidth=2)
        plt.plot(prediction, color='red', linewidth=2)
        plt.title('Output Field', fontsize=14)
        plt.legend(['Target', 'Prediction'])

        # Error plot
        ax = fig.add_subplot(1, 3, 3)
        error = target - prediction
        plt.plot(error, color='magenta')
        #plt.yscale("log")  
        plt.title('Absolute Error', fontsize=14)

        print(colored('#'*230, 'green'))

mse = sum(mse_list) / len(mse_list)
print("Mean Squared Error Test :\n", mse)
# Out:
# Loaded best model parameters
# TEST SAMPLE 1
# Rel. L2 Error = 0.0029, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 1001
# Rel. L2 Error = 0.0006, R2 score = 0.9999
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 2001
# Rel. L2 Error = 0.0004, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 3001
# Rel. L2 Error = 0.0012, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 4001
# Rel. L2 Error = 0.0013, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 5001
# Rel. L2 Error = 0.0015, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# Mean Squared Error Test :
#  3.0428176048674374e-06
