# %% [markdown]
# #### Designing a time-stepper model for Allen Cahn - Multiparameter

# %%
import jax.numpy as jnp
import numpy.random as npr
from jax import jit, grad, vmap
from jax.example_libraries.optimizers import adam
from jax import value_and_grad
from functools import partial
from jax import jacfwd, jacrev
import jax.nn as jnn
import math
from jax import random
import jax
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from flax import linen as nn
import sklearn.metrics

import argparse
import os
import time
from termcolor import colored
from scipy.io import loadmat
import scipy.io as io
import pickle

import sys
sys.path.append("../..")

import matplotlib
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 9})
import seaborn as sns
sns.set_style("white")
sns.set_style("ticks")

import warnings
warnings.filterwarnings("ignore")

# Check where gpu is enable or not
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# gpu

# %%
cluster = False
save = True

# %%
if cluster == True:
    parser = argparse.ArgumentParser()
    parser.add_argument('-seed', dest='seed', type=int, default=0, help='Seed number.')
    args = parser.parse_args()

    # Print all the arguments
    for arg in vars(args):
        print(f'{arg}: {getattr(args, arg)}')

    seed = args.seed

if cluster == False:
    seed = 0 # Seed number.

if save == True:
    resultdir = os.path.join(os.getcwd(), 'Results')
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

if save == True and cluster == True:
    orig_stdout = sys.stdout
    q = open(os.path.join(resultdir, 'outputs.txt'), 'w')
    sys.stdout = q
    print ("------START------")

print('seed = '+str(seed))
# Out:
# seed = 0

# %%
np.random.seed(seed)
key = 1234 #random.PRNGKey(seed)

# %%
# Load the data
data = loadmat('../data/multiparameter/data_022_070_AC_chebfun_more_new_aligned_healing_shorter2.mat') # Load the .mat file
# print(data)
print(data['Utrain_branch'].shape) # Inputs to branch in training
print(data['Utest_branch'].shape) # Inputs to branch in testing
print(data['Vtest_out'].shape) # Output for test samples

# Convert NumPy arrays to PyTorch tensors
inputs_train = jnp.array(data['Utrain_branch']).T
outputs_train = jnp.array(data['Vtrain_out']).T
inputs_test = jnp.array(data['Utest_branch']).T
outputs_test = jnp.array(data['Vtest_out']).T
grid = jnp.array(data['Ytrain_trunk'])
#print("grid:", grid)

# Check the shapes of the subsets
print("Shape of inputs_train:", inputs_train.shape)
print("Shape of inputs_test:", inputs_test.shape)
print("Shape of outputs_train:", outputs_train.shape)
print("Shape of outputs_test:", outputs_test.shape)
print('#'*100)
# Out:
# (101, 22259)
# (101, 5565)
# (100, 5565)
# 2024-11-29 16:12:19.725661: W external/xla/xla/service/gpu/nvptx_compiler.cc:765] The NVIDIA driver's CUDA version is 12.1 which is older than the ptxas CUDA version (12.6.77). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# Shape of inputs_train: (22259, 101)
# Shape of inputs_test: (5565, 101)
# Shape of outputs_train: (22259, 100)
# Shape of outputs_test: (5565, 100)
# ####################################################################################################

# %%
# Initialize the Glorot (Xavier) normal distribution for weight initialization
initializer = jax.nn.initializers.glorot_normal()

def init_glorot_params(layer_sizes, key = random.PRNGKey(seed)):
    """
    Initialize the parameters of the neural network using Glorot (Xavier) initialization.

    Args:
    layer_sizes (list): List of integers representing the size of each layer.
    key (PRNGKey): Random number generator key for reproducibility.

    Returns:
    list: List of tuples, each containing weights and biases for a layer.
    """
    return [(initializer(key, (m, n), jnp.float32), jnp.zeros(n))
            for m, n, in zip(layer_sizes[:-1], layer_sizes[1:])]

def BranchNet(params, x):
    """
    Implement the branch network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (array): Input to the branch network.

    Returns:
    array: Output of the branch network.
    """
    def single_forward(params, x):
        for w, b in params:
            outputs = jnp.dot(x, w) + b
            x = jnn.silu(outputs)
        return outputs

    return vmap(partial(single_forward, params))(x)

def TrunkNet(params, x):
    """
    Implement the trunk network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (float): First input to the trunk network.
    t (float): Second input to the trunk network.

    Returns:
    array: Output of the trunk network.
    """
    inputs = jnp.array(x)
    for w, b in params:
        outputs = jnp.dot(x, w) + b
        x = jnn.silu(outputs)
    return outputs

@jit
def DeepONet(params, branch_inputs, trunk_inputs):
    """
    Implement the complete DeepONet architecture.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.

    Returns:
    array: Output of the DeepONet.
    """
    params_branch, params_trunk = params
    branch_outputs = lambda x: BranchNet(params_branch, x)
    b_out = branch_outputs(branch_inputs)
    trunk_output = lambda y: TrunkNet(params_trunk, y)
    t_out = trunk_output(trunk_inputs)
    results = jnp.einsum('ik, lk -> il',b_out, t_out)
    return results

# network parameters.
p = 300 # Number of output neurons in both the branch and trunk net outputs.
nx = 101
input_neurons_branch = nx # m
input_neurons_trunk = 1

layer_sizes_b = [input_neurons_branch] + [100]*6 + [p]
layer_sizes_t = [input_neurons_trunk] + [100]*6 + [p]

params_branch = init_glorot_params(layer_sizes=layer_sizes_b)
params_trunk = init_glorot_params(layer_sizes=layer_sizes_t)

params= (params_branch, params_trunk)

def objective(params, branch_inputs, trunk_inputs, target_values):
    """
    Define the objective function (loss function) for training.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values to compare against.

    Returns:
    float: Mean squared error loss.
    """
    predictions = DeepONet(params, branch_inputs, trunk_inputs)
    loss_mse = jnp.mean((predictions - target_values)**2)
    return loss_mse


# Adam optimizer
@jit
def resnet_update(params, branch_input, trunk_inputs, target_values, opt_state):
    """
    Compute the gradient for a batch and update the parameters.

    Args:
    params (tuple): Current network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values.
    opt_state: Current state of the optimizer.

    Returns:
    tuple: Updated parameters, updated optimizer state, and current loss value.
    """
    value, grads = value_and_grad(objective)(params, branch_input, trunk_inputs, target_values)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, value

# Initialize the Adam optimizer
opt_init, opt_update, get_params = adam(step_size=1e-3, b1=0.9, b2=0.999, eps=1e-08)
opt_state = opt_init(params)

bs = 22259 #batch size
iteration_list, loss_list, test_loss_list = [], [], []
iteration = 0

n_epochs = 1000000
num_samples = len(inputs_train)

# test input preparation
branch_inputs_test = inputs_test
targets = outputs_test

# %%
def save_model_params(params, resultdir, filename='model_params.pkl'):
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

    save_path = os.path.join(resultdir, filename)
    with open(save_path, 'wb') as f:
        pickle.dump(params, f)

def load_model_params(resultdir, filename='model_params.pkl'):
    load_path = os.path.join(resultdir, filename)
    with open(load_path, 'rb') as f:
        params = pickle.load(f)
    return params

# Saving
if save:
    save_model_params(params, resultdir)

# Loading (uncomment when needed)
# model_params = load_model_params(resultdir)

# %%
## Training of DeepONet
start = time.time() # start time of training
best_test_mse = float('inf')  # Initialize with infinity

# Save initial model at 0th iteration
save_model_params(params, resultdir, filename='model_params_best.pkl')
print("Saved initial model at iteration 0")

for iteration in range(n_epochs):
    indices = jax.random.permutation(jax.random.PRNGKey(0), num_samples)
    batch_index = indices[0:bs]
    inputs_train_shuffled = inputs_train[batch_index]
    outputs_train_shuffled = outputs_train[batch_index]
    target_values = outputs_train_shuffled
    branch_inputs = inputs_train_shuffled
    trunk_inputs = grid
    params, opt_state, value = resnet_update(params, branch_inputs, trunk_inputs, target_values, opt_state)

    if iteration % 1000 == 0:
        params_branch, params_trunk = params
        predictions = DeepONet(params, branch_inputs, trunk_inputs)
        test_mse = jnp.mean((predictions - target_values)**2)

        # Compare current test error with the best so far
        if test_mse < best_test_mse:
            best_test_mse = test_mse
            # Save the model as it's the best so far
            save_model_params(params, resultdir, filename='model_params_best.pkl')
            print(f"New best model saved at iteration {iteration} with test MSE: {test_mse:.7f}")

        finish = time.time() - start
        print(f"Iteration: {iteration:3d}, Train loss: {objective(params, branch_inputs, trunk_inputs, target_values):.7f}, Test loss: {test_mse:.7f}, Best test loss: {best_test_mse:.7f}, Time: {finish:.2f}")

    iteration_list.append(iteration)
    loss_list.append(objective(params, branch_inputs, trunk_inputs, target_values))
    test_loss_list.append(test_mse)

if save:
    np.save(os.path.join(resultdir, 'iteration_list.npy'), np.asarray(iteration_list))
    np.save(os.path.join(resultdir, 'loss_list.npy'), np.asarray(loss_list))
    np.save(os.path.join(resultdir, 'test_loss_list.npy'), np.asarray(test_loss_list))

# Plotting code remains the same
plt.figure()
plt.plot(iteration_list, loss_list, 'g', label='Training loss')
plt.plot(iteration_list, test_loss_list, '-b', label='Test loss')
plt.yscale("log")
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

if save:
    plt.savefig(os.path.join(resultdir, 'loss_plot.pdf'))

# end timer
finish = time.time() - start
print("Time (sec) to complete:\n" + str(finish))
# Out:
# Saved initial model at iteration 0
# New best model saved at iteration 0 with test MSE: 0.2431327
# Iteration:   0, Train loss: 0.2431327, Test loss: 0.2431327, Best test loss: 0.2431327, Time: 8.00
# New best model saved at iteration 1000 with test MSE: 0.0007649
# Iteration: 1000, Train loss: 0.0007649, Test loss: 0.0007649, Best test loss: 0.0007649, Time: 11.95
# New best model saved at iteration 2000 with test MSE: 0.0006144
# Iteration: 2000, Train loss: 0.0006144, Test loss: 0.0006144, Best test loss: 0.0006144, Time: 15.95
# New best model saved at iteration 3000 with test MSE: 0.0003514
# Iteration: 3000, Train loss: 0.0003514, Test loss: 0.0003514, Best test loss: 0.0003514, Time: 20.11
# New best model saved at iteration 4000 with test MSE: 0.0002955
# Iteration: 4000, Train loss: 0.0002955, Test loss: 0.0002955, Best test loss: 0.0002955, Time: 24.52
# New best model saved at iteration 5000 with test MSE: 0.0002828
# Iteration: 5000, Train loss: 0.0002828, Test loss: 0.0002828, Best test loss: 0.0002828, Time: 29.70
# New best model saved at iteration 6000 with test MSE: 0.0002347
# Iteration: 6000, Train loss: 0.0002347, Test loss: 0.0002347, Best test loss: 0.0002347, Time: 34.91
# New best model saved at iteration 7000 with test MSE: 0.0002313
# Iteration: 7000, Train loss: 0.0002313, Test loss: 0.0002313, Best test loss: 0.0002313, Time: 40.06
# New best model saved at iteration 8000 with test MSE: 0.0000863
# Iteration: 8000, Train loss: 0.0000863, Test loss: 0.0000863, Best test loss: 0.0000863, Time: 43.83
# New best model saved at iteration 9000 with test MSE: 0.0000532
# Iteration: 9000, Train loss: 0.0000532, Test loss: 0.0000532, Best test loss: 0.0000532, Time: 47.51
# New best model saved at iteration 10000 with test MSE: 0.0000340
# Iteration: 10000, Train loss: 0.0000340, Test loss: 0.0000340, Best test loss: 0.0000340, Time: 51.28
# New best model saved at iteration 11000 with test MSE: 0.0000273
# Iteration: 11000, Train loss: 0.0000273, Test loss: 0.0000273, Best test loss: 0.0000273, Time: 55.05
# Iteration: 12000, Train loss: 0.0001382, Test loss: 0.0001382, Best test loss: 0.0000273, Time: 58.79
# Iteration: 13000, Train loss: 0.0000840, Test loss: 0.0000840, Best test loss: 0.0000273, Time: 62.50
# Iteration: 14000, Train loss: 0.0000366, Test loss: 0.0000366, Best test loss: 0.0000273, Time: 66.24
# Iteration: 15000, Train loss: 0.0000312, Test loss: 0.0000312, Best test loss: 0.0000273, Time: 69.99
# Iteration: 16000, Train loss: 0.0000273, Test loss: 0.0000273, Best test loss: 0.0000273, Time: 73.68
# New best model saved at iteration 17000 with test MSE: 0.0000259
# Iteration: 17000, Train loss: 0.0000259, Test loss: 0.0000259, Best test loss: 0.0000259, Time: 77.46
# New best model saved at iteration 18000 with test MSE: 0.0000252
# Iteration: 18000, Train loss: 0.0000252, Test loss: 0.0000252, Best test loss: 0.0000252, Time: 81.26
# Iteration: 19000, Train loss: 0.0000342, Test loss: 0.0000342, Best test loss: 0.0000252, Time: 85.04
# Iteration: 20000, Train loss: 0.0000326, Test loss: 0.0000326, Best test loss: 0.0000252, Time: 88.76
# New best model saved at iteration 21000 with test MSE: 0.0000243
# Iteration: 21000, Train loss: 0.0000243, Test loss: 0.0000243, Best test loss: 0.0000243, Time: 92.52
# Iteration: 22000, Train loss: 0.0000420, Test loss: 0.0000420, Best test loss: 0.0000243, Time: 96.26
# Iteration: 23000, Train loss: 0.0000253, Test loss: 0.0000253, Best test loss: 0.0000243, Time: 100.00
# New best model saved at iteration 24000 with test MSE: 0.0000225
# Iteration: 24000, Train loss: 0.0000225, Test loss: 0.0000225, Best test loss: 0.0000225, Time: 103.78
# Iteration: 25000, Train loss: 0.0000232, Test loss: 0.0000232, Best test loss: 0.0000225, Time: 107.51
# New best model saved at iteration 26000 with test MSE: 0.0000216
# Iteration: 26000, Train loss: 0.0000216, Test loss: 0.0000216, Best test loss: 0.0000216, Time: 111.19
# Iteration: 27000, Train loss: 0.0000305, Test loss: 0.0000305, Best test loss: 0.0000216, Time: 114.84
# New best model saved at iteration 28000 with test MSE: 0.0000182
# Iteration: 28000, Train loss: 0.0000182, Test loss: 0.0000182, Best test loss: 0.0000182, Time: 118.50
# Iteration: 29000, Train loss: 0.0000607, Test loss: 0.0000607, Best test loss: 0.0000182, Time: 122.15
# Iteration: 30000, Train loss: 0.0000188, Test loss: 0.0000188, Best test loss: 0.0000182, Time: 125.84
# New best model saved at iteration 31000 with test MSE: 0.0000165
# Iteration: 31000, Train loss: 0.0000165, Test loss: 0.0000165, Best test loss: 0.0000165, Time: 129.51
# Iteration: 32000, Train loss: 0.0000167, Test loss: 0.0000167, Best test loss: 0.0000165, Time: 133.16
# New best model saved at iteration 33000 with test MSE: 0.0000154
# Iteration: 33000, Train loss: 0.0000154, Test loss: 0.0000154, Best test loss: 0.0000154, Time: 136.84
# Iteration: 34000, Train loss: 0.0000160, Test loss: 0.0000160, Best test loss: 0.0000154, Time: 140.51
# New best model saved at iteration 35000 with test MSE: 0.0000154
# Iteration: 35000, Train loss: 0.0000154, Test loss: 0.0000154, Best test loss: 0.0000154, Time: 144.28
# New best model saved at iteration 36000 with test MSE: 0.0000140
# Iteration: 36000, Train loss: 0.0000140, Test loss: 0.0000140, Best test loss: 0.0000140, Time: 148.06
# New best model saved at iteration 37000 with test MSE: 0.0000128
# Iteration: 37000, Train loss: 0.0000128, Test loss: 0.0000128, Best test loss: 0.0000128, Time: 151.84
# New best model saved at iteration 38000 with test MSE: 0.0000109
# Iteration: 38000, Train loss: 0.0000109, Test loss: 0.0000109, Best test loss: 0.0000109, Time: 155.55
# New best model saved at iteration 39000 with test MSE: 0.0000105
# Iteration: 39000, Train loss: 0.0000105, Test loss: 0.0000105, Best test loss: 0.0000105, Time: 159.23
# Iteration: 40000, Train loss: 0.0000144, Test loss: 0.0000144, Best test loss: 0.0000105, Time: 162.93
# New best model saved at iteration 41000 with test MSE: 0.0000076
# Iteration: 41000, Train loss: 0.0000076, Test loss: 0.0000076, Best test loss: 0.0000076, Time: 166.58
# Iteration: 42000, Train loss: 0.0000121, Test loss: 0.0000121, Best test loss: 0.0000076, Time: 170.27
# Iteration: 43000, Train loss: 0.0000445, Test loss: 0.0000445, Best test loss: 0.0000076, Time: 173.95
# Iteration: 44000, Train loss: 0.0000145, Test loss: 0.0000145, Best test loss: 0.0000076, Time: 177.67
# Iteration: 45000, Train loss: 0.0000117, Test loss: 0.0000117, Best test loss: 0.0000076, Time: 181.32
# Iteration: 46000, Train loss: 0.0000100, Test loss: 0.0000100, Best test loss: 0.0000076, Time: 185.07
# Iteration: 47000, Train loss: 0.0000107, Test loss: 0.0000107, Best test loss: 0.0000076, Time: 188.89
# Iteration: 48000, Train loss: 0.0000080, Test loss: 0.0000080, Best test loss: 0.0000076, Time: 192.71
# Iteration: 49000, Train loss: 0.0000119, Test loss: 0.0000119, Best test loss: 0.0000076, Time: 196.48
# New best model saved at iteration 50000 with test MSE: 0.0000066
# Iteration: 50000, Train loss: 0.0000066, Test loss: 0.0000066, Best test loss: 0.0000066, Time: 200.27
# New best model saved at iteration 51000 with test MSE: 0.0000046
# Iteration: 51000, Train loss: 0.0000046, Test loss: 0.0000046, Best test loss: 0.0000046, Time: 204.23
# Iteration: 52000, Train loss: 0.0000151, Test loss: 0.0000151, Best test loss: 0.0000046, Time: 208.23
# Iteration: 53000, Train loss: 0.0000055, Test loss: 0.0000055, Best test loss: 0.0000046, Time: 212.27
# Iteration: 54000, Train loss: 0.0000067, Test loss: 0.0000067, Best test loss: 0.0000046, Time: 217.39
# New best model saved at iteration 55000 with test MSE: 0.0000045
# Iteration: 55000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000045, Time: 222.50
# New best model saved at iteration 56000 with test MSE: 0.0000043
# Iteration: 56000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000043, Time: 227.32
# New best model saved at iteration 57000 with test MSE: 0.0000034
# Iteration: 57000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000034, Time: 231.37
# Iteration: 58000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000034, Time: 235.06
# Iteration: 59000, Train loss: 0.0000082, Test loss: 0.0000082, Best test loss: 0.0000034, Time: 238.81
# Iteration: 60000, Train loss: 0.0000099, Test loss: 0.0000099, Best test loss: 0.0000034, Time: 242.50
# New best model saved at iteration 61000 with test MSE: 0.0000021
# Iteration: 61000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 246.37
# Iteration: 62000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000021, Time: 250.11
# New best model saved at iteration 63000 with test MSE: 0.0000017
# Iteration: 63000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 253.87
# New best model saved at iteration 64000 with test MSE: 0.0000017
# Iteration: 64000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 257.56
# Iteration: 65000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000017, Time: 261.29
# Iteration: 66000, Train loss: 0.0000095, Test loss: 0.0000095, Best test loss: 0.0000017, Time: 265.01
# New best model saved at iteration 67000 with test MSE: 0.0000016
# Iteration: 67000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000016, Time: 268.73
# Iteration: 68000, Train loss: 0.0000344, Test loss: 0.0000344, Best test loss: 0.0000016, Time: 272.48
# Iteration: 69000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000016, Time: 276.19
# Iteration: 70000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000016, Time: 279.87
# New best model saved at iteration 71000 with test MSE: 0.0000015
# Iteration: 71000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000015, Time: 283.59
# New best model saved at iteration 72000 with test MSE: 0.0000015
# Iteration: 72000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000015, Time: 287.33
# Iteration: 73000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000015, Time: 291.02
# Iteration: 74000, Train loss: 0.0000952, Test loss: 0.0000952, Best test loss: 0.0000015, Time: 294.74
# Iteration: 75000, Train loss: 0.0000194, Test loss: 0.0000194, Best test loss: 0.0000015, Time: 298.45
# Iteration: 76000, Train loss: 0.0000241, Test loss: 0.0000241, Best test loss: 0.0000015, Time: 302.17
# Iteration: 77000, Train loss: 0.0000076, Test loss: 0.0000076, Best test loss: 0.0000015, Time: 305.86
# Iteration: 78000, Train loss: 0.0000046, Test loss: 0.0000046, Best test loss: 0.0000015, Time: 309.56
# Iteration: 79000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000015, Time: 313.26
# Iteration: 80000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000015, Time: 316.99
# Iteration: 81000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000015, Time: 320.71
# New best model saved at iteration 82000 with test MSE: 0.0000015
# Iteration: 82000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000015, Time: 324.47
# Iteration: 83000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000015, Time: 328.21
# Iteration: 84000, Train loss: 0.0000051, Test loss: 0.0000051, Best test loss: 0.0000015, Time: 331.94
# Iteration: 85000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000015, Time: 335.66
# New best model saved at iteration 86000 with test MSE: 0.0000011
# Iteration: 86000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000011, Time: 339.36
# Iteration: 87000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000011, Time: 343.12
# Iteration: 88000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000011, Time: 346.86
# Iteration: 89000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000011, Time: 350.57
# Iteration: 90000, Train loss: 0.0000038, Test loss: 0.0000038, Best test loss: 0.0000011, Time: 354.28
# Iteration: 91000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000011, Time: 358.01
# Iteration: 92000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000011, Time: 361.74
# Iteration: 93000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000011, Time: 365.48
# Iteration: 94000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000011, Time: 369.23
# Iteration: 95000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000011, Time: 373.00
# New best model saved at iteration 96000 with test MSE: 0.0000008
# Iteration: 96000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 376.74
# Iteration: 97000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000008, Time: 380.47
# Iteration: 98000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000008, Time: 384.16
# Iteration: 99000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000008, Time: 387.85
# Iteration: 100000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000008, Time: 391.67
# Iteration: 101000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000008, Time: 395.58
# Iteration: 102000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000008, Time: 399.62
# Iteration: 103000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000008, Time: 404.79
# Iteration: 104000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000008, Time: 409.79
# Iteration: 105000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000008, Time: 414.52
# Iteration: 106000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000008, Time: 418.71
# Iteration: 107000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000008, Time: 422.46
# Iteration: 108000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000008, Time: 426.20
# Iteration: 109000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000008, Time: 429.92
# Iteration: 110000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000008, Time: 433.67
# Iteration: 111000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000008, Time: 437.41
# Iteration: 112000, Train loss: 0.0000099, Test loss: 0.0000099, Best test loss: 0.0000008, Time: 441.16
# Iteration: 113000, Train loss: 0.0000058, Test loss: 0.0000058, Best test loss: 0.0000008, Time: 444.91
# Iteration: 114000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000008, Time: 448.65
# Iteration: 115000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000008, Time: 452.41
# Iteration: 116000, Train loss: 0.0000099, Test loss: 0.0000099, Best test loss: 0.0000008, Time: 456.22
# Iteration: 117000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000008, Time: 460.04
# Iteration: 118000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000008, Time: 463.86
# Iteration: 119000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000008, Time: 467.61
# Iteration: 120000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000008, Time: 471.34
# Iteration: 121000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000008, Time: 475.14
# Iteration: 122000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000008, Time: 478.95
# Iteration: 123000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000008, Time: 482.76
# Iteration: 124000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000008, Time: 486.59
# Iteration: 125000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000008, Time: 490.44
# Iteration: 126000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000008, Time: 494.29
# Iteration: 127000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000008, Time: 498.15
# Iteration: 128000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000008, Time: 501.97
# Iteration: 129000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000008, Time: 505.78
# Iteration: 130000, Train loss: 0.0000090, Test loss: 0.0000090, Best test loss: 0.0000008, Time: 509.63
# New best model saved at iteration 131000 with test MSE: 0.0000008
# Iteration: 131000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 513.45
# Iteration: 132000, Train loss: 0.0000056, Test loss: 0.0000056, Best test loss: 0.0000008, Time: 517.20
# Iteration: 133000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000008, Time: 521.00
# Iteration: 134000, Train loss: 0.0000039, Test loss: 0.0000039, Best test loss: 0.0000008, Time: 524.75
# Iteration: 135000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000008, Time: 528.51
# Iteration: 136000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000008, Time: 532.22
# Iteration: 137000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000008, Time: 536.02
# Iteration: 138000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000008, Time: 539.84
# Iteration: 139000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000008, Time: 543.64
# Iteration: 140000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000008, Time: 547.44
# Iteration: 141000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000008, Time: 551.27
# Iteration: 142000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000008, Time: 555.08
# Iteration: 143000, Train loss: 0.0000116, Test loss: 0.0000116, Best test loss: 0.0000008, Time: 558.91
# Iteration: 144000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000008, Time: 562.74
# Iteration: 145000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000008, Time: 566.58
# Iteration: 146000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000008, Time: 570.35
# Iteration: 147000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000008, Time: 574.12
# Iteration: 148000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000008, Time: 578.12
# Iteration: 149000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000008, Time: 582.09
# Iteration: 150000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000008, Time: 586.06
# Iteration: 151000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000008, Time: 590.72
# Iteration: 152000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000008, Time: 596.26
# Iteration: 153000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000008, Time: 601.66
# New best model saved at iteration 154000 with test MSE: 0.0000007
# Iteration: 154000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 606.53
# Iteration: 155000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000007, Time: 610.59
# Iteration: 156000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000007, Time: 614.38
# Iteration: 157000, Train loss: 0.0000072, Test loss: 0.0000072, Best test loss: 0.0000007, Time: 618.16
# Iteration: 158000, Train loss: 0.0000029, Test loss: 0.0000029, Best test loss: 0.0000007, Time: 621.96
# Iteration: 159000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000007, Time: 625.79
# Iteration: 160000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000007, Time: 629.64
# Iteration: 161000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000007, Time: 633.46
# Iteration: 162000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000007, Time: 637.27
# Iteration: 163000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000007, Time: 641.09
# Iteration: 164000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000007, Time: 644.88
# Iteration: 165000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000007, Time: 648.69
# Iteration: 166000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000007, Time: 652.47
# Iteration: 167000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 656.24
# Iteration: 168000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 660.02
# Iteration: 169000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000007, Time: 663.81
# Iteration: 170000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000007, Time: 667.61
# Iteration: 171000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 671.40
# Iteration: 172000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000007, Time: 675.22
# Iteration: 173000, Train loss: 0.0000075, Test loss: 0.0000075, Best test loss: 0.0000007, Time: 678.97
# Iteration: 174000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000007, Time: 682.73
# Iteration: 175000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000007, Time: 686.47
# Iteration: 176000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000007, Time: 690.21
# Iteration: 177000, Train loss: 0.0000060, Test loss: 0.0000060, Best test loss: 0.0000007, Time: 693.97
# Iteration: 178000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 697.71
# Iteration: 179000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000007, Time: 701.46
# New best model saved at iteration 180000 with test MSE: 0.0000007
# Iteration: 180000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 705.22
# New best model saved at iteration 181000 with test MSE: 0.0000007
# Iteration: 181000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 708.99
# Iteration: 182000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000007, Time: 712.72
# Iteration: 183000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000007, Time: 716.44
# Iteration: 184000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000007, Time: 720.16
# Iteration: 185000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 723.92
# Iteration: 186000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 727.66
# Iteration: 187000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000007, Time: 731.42
# Iteration: 188000, Train loss: 0.0000039, Test loss: 0.0000039, Best test loss: 0.0000007, Time: 735.17
# Iteration: 189000, Train loss: 0.0000029, Test loss: 0.0000029, Best test loss: 0.0000007, Time: 738.92
# Iteration: 190000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000007, Time: 742.71
# Iteration: 191000, Train loss: 0.0000120, Test loss: 0.0000120, Best test loss: 0.0000007, Time: 746.50
# Iteration: 192000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000007, Time: 750.29
# Iteration: 193000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000007, Time: 754.06
# New best model saved at iteration 194000 with test MSE: 0.0000006
# Iteration: 194000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000006, Time: 757.83
# New best model saved at iteration 195000 with test MSE: 0.0000005
# Iteration: 195000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 761.60
# Iteration: 196000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000005, Time: 765.37
# Iteration: 197000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 769.12
# Iteration: 198000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 772.92
# Iteration: 199000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 776.82
# Iteration: 200000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 781.09
# Iteration: 201000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 786.25
# Iteration: 202000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000005, Time: 791.34
# Iteration: 203000, Train loss: 0.0000149, Test loss: 0.0000149, Best test loss: 0.0000005, Time: 796.36
# Iteration: 204000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000005, Time: 800.13
# Iteration: 205000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000005, Time: 803.88
# Iteration: 206000, Train loss: 0.0000125, Test loss: 0.0000125, Best test loss: 0.0000005, Time: 807.62
# Iteration: 207000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000005, Time: 811.38
# Iteration: 208000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000005, Time: 815.14
# Iteration: 209000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000005, Time: 818.91
# Iteration: 210000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 822.67
# Iteration: 211000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000005, Time: 826.41
# Iteration: 212000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000005, Time: 830.16
# Iteration: 213000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000005, Time: 833.92
# Iteration: 214000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000005, Time: 837.68
# Iteration: 215000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 841.45
# New best model saved at iteration 216000 with test MSE: 0.0000004
# Iteration: 216000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 845.22
# Iteration: 217000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 849.02
# Iteration: 218000, Train loss: 0.0000361, Test loss: 0.0000361, Best test loss: 0.0000004, Time: 852.80
# Iteration: 219000, Train loss: 0.0000069, Test loss: 0.0000069, Best test loss: 0.0000004, Time: 856.53
# Iteration: 220000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000004, Time: 860.24
# Iteration: 221000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000004, Time: 863.99
# Iteration: 222000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000004, Time: 867.73
# Iteration: 223000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000004, Time: 871.47
# Iteration: 224000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000004, Time: 875.21
# Iteration: 225000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000004, Time: 879.01
# Iteration: 226000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000004, Time: 882.85
# Iteration: 227000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000004, Time: 886.66
# Iteration: 228000, Train loss: 0.0000035, Test loss: 0.0000035, Best test loss: 0.0000004, Time: 890.51
# Iteration: 229000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000004, Time: 894.36
# Iteration: 230000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000004, Time: 898.17
# Iteration: 231000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000004, Time: 902.00
# Iteration: 232000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000004, Time: 905.86
# Iteration: 233000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000004, Time: 909.71
# Iteration: 234000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 913.57
# Iteration: 235000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 917.40
# Iteration: 236000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000004, Time: 921.21
# Iteration: 237000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 925.01
# Iteration: 238000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000004, Time: 928.81
# Iteration: 239000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000004, Time: 932.62
# Iteration: 240000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000004, Time: 936.43
# Iteration: 241000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000004, Time: 940.23
# Iteration: 242000, Train loss: 0.0000059, Test loss: 0.0000059, Best test loss: 0.0000004, Time: 944.03
# Iteration: 243000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 947.80
# Iteration: 244000, Train loss: 0.0000058, Test loss: 0.0000058, Best test loss: 0.0000004, Time: 951.58
# Iteration: 245000, Train loss: 0.0000075, Test loss: 0.0000075, Best test loss: 0.0000004, Time: 955.36
# Iteration: 246000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 959.18
# Iteration: 247000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000004, Time: 963.14
# Iteration: 248000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000004, Time: 967.04
# Iteration: 249000, Train loss: 0.0000121, Test loss: 0.0000121, Best test loss: 0.0000004, Time: 972.16
# Iteration: 250000, Train loss: 0.0000041, Test loss: 0.0000041, Best test loss: 0.0000004, Time: 977.37
# Iteration: 251000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000004, Time: 982.23
# Iteration: 252000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000004, Time: 986.53
# Iteration: 253000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000004, Time: 990.31
# Iteration: 254000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000004, Time: 994.07
# Iteration: 255000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000004, Time: 997.84
# Iteration: 256000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000004, Time: 1001.62
# Iteration: 257000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000004, Time: 1005.72
# Iteration: 258000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000004, Time: 1009.54
# Iteration: 259000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000004, Time: 1013.32
# Iteration: 260000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000004, Time: 1017.10
# Iteration: 261000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000004, Time: 1020.86
# New best model saved at iteration 262000 with test MSE: 0.0000002
# Iteration: 262000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1024.64
# Iteration: 263000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1028.38
# Iteration: 264000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000002, Time: 1032.14
# Iteration: 265000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1036.00
# Iteration: 266000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1039.87
# Iteration: 267000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000002, Time: 1043.64
# Iteration: 268000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1047.44
# Iteration: 269000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1051.16
# Iteration: 270000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1054.90
# Iteration: 271000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000002, Time: 1058.68
# Iteration: 272000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1062.45
# Iteration: 273000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1066.22
# Iteration: 274000, Train loss: 0.0000047, Test loss: 0.0000047, Best test loss: 0.0000002, Time: 1070.06
# Iteration: 275000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000002, Time: 1073.90
# Iteration: 276000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1077.75
# Iteration: 277000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1081.56
# Iteration: 278000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000002, Time: 1085.34
# Iteration: 279000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1089.20
# Iteration: 280000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000002, Time: 1093.04
# Iteration: 281000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000002, Time: 1096.94
# Iteration: 282000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1100.82
# Iteration: 283000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000002, Time: 1104.70
# Iteration: 284000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1108.49
# Iteration: 285000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1112.33
# Iteration: 286000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1116.14
# Iteration: 287000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1119.97
# Iteration: 288000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000002, Time: 1123.81
# Iteration: 289000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000002, Time: 1127.65
# Iteration: 290000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1131.46
# Iteration: 291000, Train loss: 0.0000068, Test loss: 0.0000068, Best test loss: 0.0000002, Time: 1135.29
# Iteration: 292000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000002, Time: 1139.11
# Iteration: 293000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1142.96
# Iteration: 294000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1146.78
# Iteration: 295000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1150.87
# Iteration: 296000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1154.84
# Iteration: 297000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1160.19
# Iteration: 298000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1165.52
# Iteration: 299000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1170.50
# Iteration: 300000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1174.66
# Iteration: 301000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1178.47
# Iteration: 302000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1182.29
# Iteration: 303000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1186.10
# Iteration: 304000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1189.92
# Iteration: 305000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1193.75
# Iteration: 306000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1197.56
# Iteration: 307000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000002, Time: 1201.41
# Iteration: 308000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1205.28
# Iteration: 309000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1209.13
# Iteration: 310000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1212.99
# Iteration: 311000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1216.79
# Iteration: 312000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1220.65
# Iteration: 313000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1224.56
# Iteration: 314000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1228.44
# Iteration: 315000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1232.23
# Iteration: 316000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1236.01
# Iteration: 317000, Train loss: 0.0000075, Test loss: 0.0000075, Best test loss: 0.0000002, Time: 1239.78
# Iteration: 318000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1243.55
# Iteration: 319000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1247.32
# Iteration: 320000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1251.09
# Iteration: 321000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1254.87
# Iteration: 322000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1258.64
# Iteration: 323000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1262.41
# Iteration: 324000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1266.18
# Iteration: 325000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1269.94
# Iteration: 326000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1273.70
# Iteration: 327000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000002, Time: 1277.47
# Iteration: 328000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1281.28
# Iteration: 329000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1285.11
# Iteration: 330000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1288.92
# Iteration: 331000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1292.73
# Iteration: 332000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000002, Time: 1296.52
# Iteration: 333000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1300.29
# Iteration: 334000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1304.05
# Iteration: 335000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1307.79
# Iteration: 336000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1311.55
# Iteration: 337000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000002, Time: 1315.30
# Iteration: 338000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1319.04
# Iteration: 339000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1322.80
# Iteration: 340000, Train loss: 0.0000032, Test loss: 0.0000032, Best test loss: 0.0000002, Time: 1326.56
# Iteration: 341000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1330.33
# Iteration: 342000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1334.11
# Iteration: 343000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000002, Time: 1337.90
# Iteration: 344000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1341.70
# Iteration: 345000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1345.62
# Iteration: 346000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 1349.73
# Iteration: 347000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000002, Time: 1354.54
# Iteration: 348000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1359.37
# Iteration: 349000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1363.97
# Iteration: 350000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1368.08
# Iteration: 351000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1371.84
# New best model saved at iteration 352000 with test MSE: 0.0000002
# Iteration: 352000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1375.59
# New best model saved at iteration 353000 with test MSE: 0.0000002
# Iteration: 353000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1379.35
# Iteration: 354000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 1383.09
# Iteration: 355000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000002, Time: 1386.81
# Iteration: 356000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1390.56
# Iteration: 357000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1394.37
# Iteration: 358000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1398.15
# Iteration: 359000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000002, Time: 1401.94
# Iteration: 360000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1405.74
# Iteration: 361000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1409.56
# Iteration: 362000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1413.36
# Iteration: 363000, Train loss: 0.0000050, Test loss: 0.0000050, Best test loss: 0.0000002, Time: 1417.14
# Iteration: 364000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1420.92
# Iteration: 365000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1424.70
# Iteration: 366000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1428.49
# Iteration: 367000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1432.24
# Iteration: 368000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1436.01
# Iteration: 369000, Train loss: 0.0000094, Test loss: 0.0000094, Best test loss: 0.0000002, Time: 1439.78
# Iteration: 370000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000002, Time: 1443.56
# Iteration: 371000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1447.32
# Iteration: 372000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 1451.09
# Iteration: 373000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1454.88
# New best model saved at iteration 374000 with test MSE: 0.0000001
# Iteration: 374000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1458.71
# Iteration: 375000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000001, Time: 1462.54
# Iteration: 376000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1466.33
# Iteration: 377000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1470.13
# Iteration: 378000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1473.91
# Iteration: 379000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1477.69
# Iteration: 380000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1481.47
# Iteration: 381000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1485.25
# Iteration: 382000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000001, Time: 1489.00
# Iteration: 383000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 1492.78
# Iteration: 384000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1496.53
# Iteration: 385000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000001, Time: 1500.32
# Iteration: 386000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000001, Time: 1504.08
# Iteration: 387000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1507.86
# Iteration: 388000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1511.63
# New best model saved at iteration 389000 with test MSE: 0.0000001
# Iteration: 389000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1515.40
# Iteration: 390000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000001, Time: 1519.20
# Iteration: 391000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1522.98
# Iteration: 392000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000001, Time: 1526.77
# Iteration: 393000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1530.98
# Iteration: 394000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 1534.80
# Iteration: 395000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000001, Time: 1538.97
# Iteration: 396000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000001, Time: 1543.31
# Iteration: 397000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000001, Time: 1547.65
# Iteration: 398000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 1551.92
# Iteration: 399000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000001, Time: 1556.01
# Iteration: 400000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1559.83
# Iteration: 401000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 1563.65
# Iteration: 402000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1567.46
# Iteration: 403000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 1571.25
# Iteration: 404000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000001, Time: 1575.06
# Iteration: 405000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000001, Time: 1578.86
# Iteration: 406000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1582.68
# Iteration: 407000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 1586.51
# Iteration: 408000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 1590.34
# Iteration: 409000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1594.16
# Iteration: 410000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1597.97
# Iteration: 411000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1601.77
# Iteration: 412000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1605.58
# Iteration: 413000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1609.38
# Iteration: 414000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1613.15
# Iteration: 415000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1616.95
# Iteration: 416000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1620.79
# Iteration: 417000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1624.58
# Iteration: 418000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1628.35
# Iteration: 419000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1632.16
# Iteration: 420000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1636.06
# Iteration: 421000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1639.97
# Iteration: 422000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 1643.90
# Iteration: 423000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1647.84
# Iteration: 424000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 1651.74
# Iteration: 425000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1655.54
# Iteration: 426000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000001, Time: 1659.32
# Iteration: 427000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000001, Time: 1663.10
# ...
# Iteration: 849000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3312.73
# Iteration: 850000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3316.59
# Iteration: 851000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3320.45
# Iteration: 852000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3324.31
# Iteration: 853000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3328.16
# Iteration: 854000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000001, Time: 3332.05
# Iteration: 855000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3335.92
# Iteration: 856000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3339.77
# Iteration: 857000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3343.60
# Iteration: 858000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3347.43
# Iteration: 859000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3351.25
# Iteration: 860000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3355.06
# Iteration: 861000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3358.86
# Iteration: 862000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3362.64
# Iteration: 863000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3366.43
# Iteration: 864000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000001, Time: 3370.27
# Iteration: 865000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000001, Time: 3374.11
# Iteration: 866000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3377.98
# New best model saved at iteration 867000 with test MSE: 0.0000001
# Iteration: 867000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3381.87
# Iteration: 868000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3385.74
# Iteration: 869000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3389.59
# Iteration: 870000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3393.43
# Iteration: 871000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000001, Time: 3397.25
# Iteration: 872000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3401.08
# Iteration: 873000, Train loss: 0.0000205, Test loss: 0.0000205, Best test loss: 0.0000001, Time: 3404.91
# Iteration: 874000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3408.89
# Iteration: 875000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3412.97
# Iteration: 876000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3417.04
# Iteration: 877000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3422.22
# Iteration: 878000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3427.33
# Iteration: 879000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000001, Time: 3432.22
# Iteration: 880000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3436.44
# Iteration: 881000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000001, Time: 3440.31
# Iteration: 882000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3444.18
# Iteration: 883000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3448.05
# Iteration: 884000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3451.91
# Iteration: 885000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3455.76
# Iteration: 886000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3459.58
# Iteration: 887000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 3463.38
# Iteration: 888000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3467.20
# Iteration: 889000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3471.03
# Iteration: 890000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000001, Time: 3474.86
# Iteration: 891000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3478.71
# Iteration: 892000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3482.59
# Iteration: 893000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3486.48
# Iteration: 894000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3490.37
# Iteration: 895000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3494.31
# Iteration: 896000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3498.23
# Iteration: 897000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3502.18
# Iteration: 898000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3506.06
# Iteration: 899000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3509.90
# Iteration: 900000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3513.72
# Iteration: 901000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3517.54
# Iteration: 902000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3521.35
# Iteration: 903000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3525.15
# Iteration: 904000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3528.93
# Iteration: 905000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3532.72
# Iteration: 906000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3536.55
# Iteration: 907000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3540.45
# Iteration: 908000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3544.32
# Iteration: 909000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3548.23
# Iteration: 910000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3552.17
# Iteration: 911000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3556.14
# Iteration: 912000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3560.11
# Iteration: 913000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3563.98
# Iteration: 914000, Train loss: 0.0000185, Test loss: 0.0000185, Best test loss: 0.0000001, Time: 3567.83
# Iteration: 915000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3571.64
# Iteration: 916000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3575.46
# Iteration: 917000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3579.30
# Iteration: 918000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3583.10
# Iteration: 919000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3586.90
# Iteration: 920000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000001, Time: 3590.70
# Iteration: 921000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3594.53
# Iteration: 922000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3598.39
# Iteration: 923000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3602.33
# Iteration: 924000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3606.37
# Iteration: 925000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000001, Time: 3610.50
# Iteration: 926000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3615.76
# Iteration: 927000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3620.90
# Iteration: 928000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3625.72
# Iteration: 929000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3630.01
# Iteration: 930000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3633.84
# Iteration: 931000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3637.65
# Iteration: 932000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3641.46
# Iteration: 933000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000001, Time: 3645.26
# Iteration: 934000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3649.08
# Iteration: 935000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3652.91
# Iteration: 936000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3656.76
# Iteration: 937000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3660.62
# Iteration: 938000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000001, Time: 3664.50
# Iteration: 939000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3668.39
# Iteration: 940000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000001, Time: 3672.24
# Iteration: 941000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3676.09
# Iteration: 942000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3679.95
# Iteration: 943000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3683.79
# Iteration: 944000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3687.62
# Iteration: 945000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3691.43
# Iteration: 946000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3695.24
# Iteration: 947000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000001, Time: 3699.03
# Iteration: 948000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3702.81
# Iteration: 949000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3706.62
# Iteration: 950000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3710.47
# Iteration: 951000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3714.32
# Iteration: 952000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3718.18
# Iteration: 953000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3722.09
# Iteration: 954000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3726.05
# Iteration: 955000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3729.94
# Iteration: 956000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3733.87
# Iteration: 957000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3737.73
# Iteration: 958000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3741.56
# Iteration: 959000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3745.38
# Iteration: 960000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3749.20
# Iteration: 961000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3753.09
# Iteration: 962000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000001, Time: 3756.95
# Iteration: 963000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3760.77
# Iteration: 964000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3764.61
# Iteration: 965000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3768.44
# Iteration: 966000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3772.31
# Iteration: 967000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3776.23
# Iteration: 968000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3780.12
# Iteration: 969000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3784.05
# Iteration: 970000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3787.95
# Iteration: 971000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3792.00
# Iteration: 972000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3796.06
# Iteration: 973000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3800.46
# Iteration: 974000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000001, Time: 3805.56
# Iteration: 975000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3810.53
# Iteration: 976000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3815.42
# Iteration: 977000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3819.38
# Iteration: 978000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3823.27
# Iteration: 979000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3827.18
# Iteration: 980000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3831.05
# Iteration: 981000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3834.95
# Iteration: 982000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3838.87
# Iteration: 983000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 3842.80
# Iteration: 984000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3846.74
# Iteration: 985000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 3850.66
# Iteration: 986000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3854.56
# Iteration: 987000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3858.44
# Iteration: 988000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3862.31
# Iteration: 989000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3866.17
# Iteration: 990000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000001, Time: 3870.01
# Iteration: 991000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3873.88
# Iteration: 992000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 3877.77
# Iteration: 993000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3881.67
# Iteration: 994000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 3885.60
# Iteration: 995000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 3889.56
# Iteration: 996000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 3893.52
# Iteration: 997000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 3897.49
# Iteration: 998000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 3901.46
# Iteration: 999000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000001, Time: 3905.37
# Time (sec) to complete:
# 3988.0796365737915

# %%
# params_branch, params_trunk = params
# Load the best model parameters
best_params = load_model_params(resultdir, filename='model_params_best.pkl')
print("Loaded best model parameters")

# Predictions
mse_list = []

branch_inputs = inputs_test
trunk_inputs = grid
prediction = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval) 

save_dict = {'u_test': inputs_test.T, 'v_pred': prediction.T,\
             'v_target': outputs_test.T}

io.savemat(resultdir+'/pred.mat', save_dict)

for i in range(inputs_test.shape[0]):

    branch_inputs = inputs_test[i].reshape(1, nx) 
    trunk_inputs = grid # (neval, 1) 

    prediction_i = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval)
    target_i = outputs_test[i]

    mse_i = np.mean((prediction_i - target_i)**2)
    mse_list.append(mse_i.item())

    if i % 1000 == 0:
        print(colored('TEST SAMPLE '+str(i+1), 'red'))

        r2score = metrics.r2_score(target_i.flatten(), prediction_i.flatten())
        relerror = np.linalg.norm(target_i- prediction_i) / np.linalg.norm(target_i)
        r2score = float('%.4f'%r2score)
        relerror = float('%.4f'%relerror)
        print('Rel. L2 Error = '+str(relerror)+', R2 score = '+str(r2score))

        fig = plt.figure(figsize=(15, 4))

        # Adjust subplot parameters for better spacing
        plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.3)

        # Input plot
        ax = fig.add_subplot(1, 3, 1)
        plt.plot(inputs_test[i,0:-1])
        plt.title('Input', fontsize=14)

        # Output plot
        ax = fig.add_subplot(1, 3, 2)
        target = target_i.reshape(grid.shape[0])
        prediction = prediction_i.reshape(grid.shape[0])
        plt.plot(target, color='blue', linewidth=2)
        plt.plot(prediction, color='red', linewidth=2)
        plt.title('Output Field', fontsize=14)
        plt.legend(['Target', 'Prediction'])

        # Error plot
        ax = fig.add_subplot(1, 3, 3)
        error = target - prediction
        plt.plot(error, color='magenta')
        plt.yscale("log")  
        plt.title('Absolute Error', fontsize=14)

        print(colored('#'*230, 'green'))

mse = sum(mse_list) / len(mse_list)
print("Mean Squared Error Test :\n", mse)
# Out:
# Loaded best model parameters
# TEST SAMPLE 1
# Rel. L2 Error = 0.0005, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 1001
# Rel. L2 Error = 0.0007, R2 score = 0.9999
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 2001
# Rel. L2 Error = 0.0008, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 3001
# Rel. L2 Error = 0.0009, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 4001
# Rel. L2 Error = 0.0008, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 5001
# Rel. L2 Error = 0.0008, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# Mean Squared Error Test :
#  1.5953532712167496e-07
