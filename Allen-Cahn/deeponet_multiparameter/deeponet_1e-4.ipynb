# %% [markdown]
# #### Designing a time-stepper model for Allen Cahn - Multiparameter

# %%
import jax.numpy as jnp
import numpy.random as npr
from jax import jit, grad, vmap
from jax.example_libraries.optimizers import adam
from jax import value_and_grad
from functools import partial
from jax import jacfwd, jacrev
import jax.nn as jnn
import math
from jax import random
import jax
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from flax import linen as nn
import sklearn.metrics

import argparse
import os
import time
from termcolor import colored
from scipy.io import loadmat
import scipy.io as io
import pickle

import sys
sys.path.append("../..")

import matplotlib
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 9})
import seaborn as sns
sns.set_style("white")
sns.set_style("ticks")

import warnings
warnings.filterwarnings("ignore")

# Check where gpu is enable or not
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# gpu

# %%
cluster = False
save = True

# %%
if cluster == True:
    parser = argparse.ArgumentParser()
    parser.add_argument('-seed', dest='seed', type=int, default=0, help='Seed number.')
    args = parser.parse_args()

    # Print all the arguments
    for arg in vars(args):
        print(f'{arg}: {getattr(args, arg)}')

    seed = args.seed

if cluster == False:
    seed = 0 # Seed number.

if save == True:
    resultdir = os.path.join(os.getcwd(), 'Results_1e-4')
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

if save == True and cluster == True:
    orig_stdout = sys.stdout
    q = open(os.path.join(resultdir, 'outputs.txt'), 'w')
    sys.stdout = q
    print ("------START------")

print('seed = '+str(seed))
# Out:
# seed = 0

# %%
np.random.seed(seed)
key = 1234 #random.PRNGKey(seed)

# %%
# Load the data
data = loadmat('../data/multiparameter/data_022_070_AC_chebfun_more_new_aligned_healing_shorter2.mat') # Load the .mat file
# print(data)
print(data['Utrain_branch'].shape) # Inputs to branch in training
print(data['Utest_branch'].shape) # Inputs to branch in testing
print(data['Vtest_out'].shape) # Output for test samples

# Convert NumPy arrays to PyTorch tensors
inputs_train = jnp.array(data['Utrain_branch']).T
outputs_train = jnp.array(data['Vtrain_out']).T
inputs_test = jnp.array(data['Utest_branch']).T
outputs_test = jnp.array(data['Vtest_out']).T
grid = jnp.array(data['Ytrain_trunk'])
#print("grid:", grid)

# Check the shapes of the subsets
print("Shape of inputs_train:", inputs_train.shape)
print("Shape of inputs_test:", inputs_test.shape)
print("Shape of outputs_train:", outputs_train.shape)
print("Shape of outputs_test:", outputs_test.shape)
print('#'*100)
# Out:
# (101, 22259)
# (101, 5565)
# (100, 5565)
# 2024-11-29 17:24:46.921921: W external/xla/xla/service/gpu/nvptx_compiler.cc:765] The NVIDIA driver's CUDA version is 12.1 which is older than the ptxas CUDA version (12.6.77). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# Shape of inputs_train: (22259, 101)
# Shape of inputs_test: (5565, 101)
# Shape of outputs_train: (22259, 100)
# Shape of outputs_test: (5565, 100)
# ####################################################################################################

# %%
# Initialize the Glorot (Xavier) normal distribution for weight initialization
initializer = jax.nn.initializers.glorot_normal()

def init_glorot_params(layer_sizes, key = random.PRNGKey(seed)):
    """
    Initialize the parameters of the neural network using Glorot (Xavier) initialization.

    Args:
    layer_sizes (list): List of integers representing the size of each layer.
    key (PRNGKey): Random number generator key for reproducibility.

    Returns:
    list: List of tuples, each containing weights and biases for a layer.
    """
    return [(initializer(key, (m, n), jnp.float32), jnp.zeros(n))
            for m, n, in zip(layer_sizes[:-1], layer_sizes[1:])]

def BranchNet(params, x):
    """
    Implement the branch network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (array): Input to the branch network.

    Returns:
    array: Output of the branch network.
    """
    def single_forward(params, x):
        for w, b in params:
            outputs = jnp.dot(x, w) + b
            x = jnn.silu(outputs)
        return outputs

    return vmap(partial(single_forward, params))(x)

def TrunkNet(params, x):
    """
    Implement the trunk network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (float): First input to the trunk network.
    t (float): Second input to the trunk network.

    Returns:
    array: Output of the trunk network.
    """
    inputs = jnp.array(x)
    for w, b in params:
        outputs = jnp.dot(x, w) + b
        x = jnn.silu(outputs)
    return outputs

@jit
def DeepONet(params, branch_inputs, trunk_inputs):
    """
    Implement the complete DeepONet architecture.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.

    Returns:
    array: Output of the DeepONet.
    """
    params_branch, params_trunk = params
    branch_outputs = lambda x: BranchNet(params_branch, x)
    b_out = branch_outputs(branch_inputs)
    trunk_output = lambda y: TrunkNet(params_trunk, y)
    t_out = trunk_output(trunk_inputs)
    results = jnp.einsum('ik, lk -> il',b_out, t_out)
    return results

# network parameters.
p = 300 # Number of output neurons in both the branch and trunk net outputs.
nx = 101
input_neurons_branch = nx # m
input_neurons_trunk = 1

layer_sizes_b = [input_neurons_branch] + [100]*6 + [p]
layer_sizes_t = [input_neurons_trunk] + [100]*6 + [p]

params_branch = init_glorot_params(layer_sizes=layer_sizes_b)
params_trunk = init_glorot_params(layer_sizes=layer_sizes_t)

params= (params_branch, params_trunk)

def objective(params, branch_inputs, trunk_inputs, target_values):
    """
    Define the objective function (loss function) for training.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values to compare against.

    Returns:
    float: Mean squared error loss.
    """
    predictions = DeepONet(params, branch_inputs, trunk_inputs)
    loss_mse = jnp.mean((predictions - target_values)**2)
    return loss_mse


# Adam optimizer
@jit
def resnet_update(params, branch_input, trunk_inputs, target_values, opt_state):
    """
    Compute the gradient for a batch and update the parameters.

    Args:
    params (tuple): Current network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values.
    opt_state: Current state of the optimizer.

    Returns:
    tuple: Updated parameters, updated optimizer state, and current loss value.
    """
    value, grads = value_and_grad(objective)(params, branch_input, trunk_inputs, target_values)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, value

# Initialize the Adam optimizer
opt_init, opt_update, get_params = adam(step_size=1e-4, b1=0.9, b2=0.999, eps=1e-08)
opt_state = opt_init(params)

bs = 22259 #batch size
iteration_list, loss_list, test_loss_list = [], [], []
iteration = 0

n_epochs = 1000000
num_samples = len(inputs_train)

# test input preparation
branch_inputs_test = inputs_test
targets = outputs_test

# %%
def save_model_params(params, resultdir, filename='model_params.pkl'):
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

    save_path = os.path.join(resultdir, filename)
    with open(save_path, 'wb') as f:
        pickle.dump(params, f)

def load_model_params(resultdir, filename='model_params.pkl'):
    load_path = os.path.join(resultdir, filename)
    with open(load_path, 'rb') as f:
        params = pickle.load(f)
    return params

# Saving
if save:
    save_model_params(params, resultdir)

# Loading (uncomment when needed)
# model_params = load_model_params(resultdir)

# %%
## Training of DeepONet
start = time.time() # start time of training
best_test_mse = float('inf')  # Initialize with infinity

# Save initial model at 0th iteration
save_model_params(params, resultdir, filename='model_params_best.pkl')
print("Saved initial model at iteration 0")

for iteration in range(n_epochs):
    indices = jax.random.permutation(jax.random.PRNGKey(0), num_samples)
    batch_index = indices[0:bs]
    inputs_train_shuffled = inputs_train[batch_index]
    outputs_train_shuffled = outputs_train[batch_index]
    target_values = outputs_train_shuffled
    branch_inputs = inputs_train_shuffled
    trunk_inputs = grid
    params, opt_state, value = resnet_update(params, branch_inputs, trunk_inputs, target_values, opt_state)

    if iteration % 1000 == 0:
        params_branch, params_trunk = params
        predictions = DeepONet(params, branch_inputs, trunk_inputs)
        test_mse = jnp.mean((predictions - target_values)**2)

        # Compare current test error with the best so far
        if test_mse < best_test_mse:
            best_test_mse = test_mse
            # Save the model as it's the best so far
            save_model_params(params, resultdir, filename='model_params_best.pkl')
            print(f"New best model saved at iteration {iteration} with test MSE: {test_mse:.7f}")

        finish = time.time() - start
        print(f"Iteration: {iteration:3d}, Train loss: {objective(params, branch_inputs, trunk_inputs, target_values):.7f}, Test loss: {test_mse:.7f}, Best test loss: {best_test_mse:.7f}, Time: {finish:.2f}")

    iteration_list.append(iteration)
    loss_list.append(objective(params, branch_inputs, trunk_inputs, target_values))
    test_loss_list.append(test_mse)

if save:
    np.save(os.path.join(resultdir, 'iteration_list.npy'), np.asarray(iteration_list))
    np.save(os.path.join(resultdir, 'loss_list.npy'), np.asarray(loss_list))
    np.save(os.path.join(resultdir, 'test_loss_list.npy'), np.asarray(test_loss_list))

# Plotting code remains the same
plt.figure()
plt.plot(iteration_list, loss_list, 'g', label='Training loss')
plt.plot(iteration_list, test_loss_list, '-b', label='Test loss')
plt.yscale("log")
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

if save:
    plt.savefig(os.path.join(resultdir, 'loss_plot.pdf'))

# end timer
finish = time.time() - start
print("Time (sec) to complete:\n" + str(finish))
# Out:
# Saved initial model at iteration 0
# New best model saved at iteration 0 with test MSE: 0.2469055
# Iteration:   0, Train loss: 0.2469055, Test loss: 0.2469055, Best test loss: 0.2469055, Time: 8.27
# New best model saved at iteration 1000 with test MSE: 0.0074729
# Iteration: 1000, Train loss: 0.0074729, Test loss: 0.0074729, Best test loss: 0.0074729, Time: 12.05
# New best model saved at iteration 2000 with test MSE: 0.0048988
# Iteration: 2000, Train loss: 0.0048988, Test loss: 0.0048988, Best test loss: 0.0048988, Time: 15.90
# New best model saved at iteration 3000 with test MSE: 0.0009346
# Iteration: 3000, Train loss: 0.0009346, Test loss: 0.0009346, Best test loss: 0.0009346, Time: 20.17
# New best model saved at iteration 4000 with test MSE: 0.0007331
# Iteration: 4000, Train loss: 0.0007331, Test loss: 0.0007331, Best test loss: 0.0007331, Time: 24.38
# New best model saved at iteration 5000 with test MSE: 0.0006238
# Iteration: 5000, Train loss: 0.0006238, Test loss: 0.0006238, Best test loss: 0.0006238, Time: 28.85
# New best model saved at iteration 6000 with test MSE: 0.0003918
# Iteration: 6000, Train loss: 0.0003918, Test loss: 0.0003918, Best test loss: 0.0003918, Time: 33.20
# New best model saved at iteration 7000 with test MSE: 0.0003633
# Iteration: 7000, Train loss: 0.0003633, Test loss: 0.0003633, Best test loss: 0.0003633, Time: 36.85
# New best model saved at iteration 8000 with test MSE: 0.0003319
# Iteration: 8000, Train loss: 0.0003319, Test loss: 0.0003319, Best test loss: 0.0003319, Time: 40.47
# New best model saved at iteration 9000 with test MSE: 0.0003063
# Iteration: 9000, Train loss: 0.0003063, Test loss: 0.0003063, Best test loss: 0.0003063, Time: 44.09
# New best model saved at iteration 10000 with test MSE: 0.0002897
# Iteration: 10000, Train loss: 0.0002897, Test loss: 0.0002897, Best test loss: 0.0002897, Time: 47.78
# Iteration: 11000, Train loss: 0.0002947, Test loss: 0.0002947, Best test loss: 0.0002897, Time: 51.45
# New best model saved at iteration 12000 with test MSE: 0.0002423
# Iteration: 12000, Train loss: 0.0002423, Test loss: 0.0002423, Best test loss: 0.0002423, Time: 55.13
# New best model saved at iteration 13000 with test MSE: 0.0001791
# Iteration: 13000, Train loss: 0.0001791, Test loss: 0.0001791, Best test loss: 0.0001791, Time: 58.82
# New best model saved at iteration 14000 with test MSE: 0.0001489
# Iteration: 14000, Train loss: 0.0001489, Test loss: 0.0001489, Best test loss: 0.0001489, Time: 62.52
# New best model saved at iteration 15000 with test MSE: 0.0001472
# Iteration: 15000, Train loss: 0.0001472, Test loss: 0.0001472, Best test loss: 0.0001472, Time: 66.16
# New best model saved at iteration 16000 with test MSE: 0.0001405
# Iteration: 16000, Train loss: 0.0001405, Test loss: 0.0001405, Best test loss: 0.0001405, Time: 69.82
# New best model saved at iteration 17000 with test MSE: 0.0001301
# Iteration: 17000, Train loss: 0.0001301, Test loss: 0.0001301, Best test loss: 0.0001301, Time: 73.46
# New best model saved at iteration 18000 with test MSE: 0.0001215
# Iteration: 18000, Train loss: 0.0001215, Test loss: 0.0001215, Best test loss: 0.0001215, Time: 77.05
# New best model saved at iteration 19000 with test MSE: 0.0001005
# Iteration: 19000, Train loss: 0.0001005, Test loss: 0.0001005, Best test loss: 0.0001005, Time: 80.66
# New best model saved at iteration 20000 with test MSE: 0.0000709
# Iteration: 20000, Train loss: 0.0000709, Test loss: 0.0000709, Best test loss: 0.0000709, Time: 84.28
# New best model saved at iteration 21000 with test MSE: 0.0000588
# Iteration: 21000, Train loss: 0.0000588, Test loss: 0.0000588, Best test loss: 0.0000588, Time: 87.95
# New best model saved at iteration 22000 with test MSE: 0.0000538
# Iteration: 22000, Train loss: 0.0000538, Test loss: 0.0000538, Best test loss: 0.0000538, Time: 91.60
# New best model saved at iteration 23000 with test MSE: 0.0000523
# Iteration: 23000, Train loss: 0.0000523, Test loss: 0.0000523, Best test loss: 0.0000523, Time: 95.23
# New best model saved at iteration 24000 with test MSE: 0.0000522
# Iteration: 24000, Train loss: 0.0000522, Test loss: 0.0000522, Best test loss: 0.0000522, Time: 98.89
# New best model saved at iteration 25000 with test MSE: 0.0000494
# Iteration: 25000, Train loss: 0.0000494, Test loss: 0.0000494, Best test loss: 0.0000494, Time: 102.54
# Iteration: 26000, Train loss: 0.0000507, Test loss: 0.0000507, Best test loss: 0.0000494, Time: 106.20
# New best model saved at iteration 27000 with test MSE: 0.0000455
# Iteration: 27000, Train loss: 0.0000455, Test loss: 0.0000455, Best test loss: 0.0000455, Time: 109.84
# Iteration: 28000, Train loss: 0.0000467, Test loss: 0.0000467, Best test loss: 0.0000455, Time: 113.48
# New best model saved at iteration 29000 with test MSE: 0.0000433
# Iteration: 29000, Train loss: 0.0000433, Test loss: 0.0000433, Best test loss: 0.0000433, Time: 117.11
# New best model saved at iteration 30000 with test MSE: 0.0000421
# Iteration: 30000, Train loss: 0.0000421, Test loss: 0.0000421, Best test loss: 0.0000421, Time: 120.80
# New best model saved at iteration 31000 with test MSE: 0.0000412
# Iteration: 31000, Train loss: 0.0000412, Test loss: 0.0000412, Best test loss: 0.0000412, Time: 124.45
# New best model saved at iteration 32000 with test MSE: 0.0000403
# Iteration: 32000, Train loss: 0.0000403, Test loss: 0.0000403, Best test loss: 0.0000403, Time: 128.04
# New best model saved at iteration 33000 with test MSE: 0.0000393
# Iteration: 33000, Train loss: 0.0000393, Test loss: 0.0000393, Best test loss: 0.0000393, Time: 131.63
# New best model saved at iteration 34000 with test MSE: 0.0000388
# Iteration: 34000, Train loss: 0.0000388, Test loss: 0.0000388, Best test loss: 0.0000388, Time: 135.29
# New best model saved at iteration 35000 with test MSE: 0.0000362
# Iteration: 35000, Train loss: 0.0000362, Test loss: 0.0000362, Best test loss: 0.0000362, Time: 138.93
# Iteration: 36000, Train loss: 0.0000367, Test loss: 0.0000367, Best test loss: 0.0000362, Time: 142.56
# New best model saved at iteration 37000 with test MSE: 0.0000336
# Iteration: 37000, Train loss: 0.0000336, Test loss: 0.0000336, Best test loss: 0.0000336, Time: 146.19
# Iteration: 38000, Train loss: 0.0000357, Test loss: 0.0000357, Best test loss: 0.0000336, Time: 149.81
# New best model saved at iteration 39000 with test MSE: 0.0000299
# Iteration: 39000, Train loss: 0.0000299, Test loss: 0.0000299, Best test loss: 0.0000299, Time: 153.43
# New best model saved at iteration 40000 with test MSE: 0.0000289
# Iteration: 40000, Train loss: 0.0000289, Test loss: 0.0000289, Best test loss: 0.0000289, Time: 157.01
# New best model saved at iteration 41000 with test MSE: 0.0000289
# Iteration: 41000, Train loss: 0.0000289, Test loss: 0.0000289, Best test loss: 0.0000289, Time: 160.61
# New best model saved at iteration 42000 with test MSE: 0.0000272
# Iteration: 42000, Train loss: 0.0000272, Test loss: 0.0000272, Best test loss: 0.0000272, Time: 164.20
# New best model saved at iteration 43000 with test MSE: 0.0000269
# Iteration: 43000, Train loss: 0.0000269, Test loss: 0.0000269, Best test loss: 0.0000269, Time: 167.84
# New best model saved at iteration 44000 with test MSE: 0.0000262
# Iteration: 44000, Train loss: 0.0000262, Test loss: 0.0000262, Best test loss: 0.0000262, Time: 171.49
# Iteration: 45000, Train loss: 0.0000264, Test loss: 0.0000264, Best test loss: 0.0000262, Time: 175.12
# New best model saved at iteration 46000 with test MSE: 0.0000258
# Iteration: 46000, Train loss: 0.0000258, Test loss: 0.0000258, Best test loss: 0.0000258, Time: 178.75
# Iteration: 47000, Train loss: 0.0000266, Test loss: 0.0000266, Best test loss: 0.0000258, Time: 182.36
# New best model saved at iteration 48000 with test MSE: 0.0000250
# Iteration: 48000, Train loss: 0.0000250, Test loss: 0.0000250, Best test loss: 0.0000250, Time: 185.99
# Iteration: 49000, Train loss: 0.0000251, Test loss: 0.0000251, Best test loss: 0.0000250, Time: 189.61
# New best model saved at iteration 50000 with test MSE: 0.0000248
# Iteration: 50000, Train loss: 0.0000248, Test loss: 0.0000248, Best test loss: 0.0000248, Time: 193.22
# New best model saved at iteration 51000 with test MSE: 0.0000245
# Iteration: 51000, Train loss: 0.0000245, Test loss: 0.0000245, Best test loss: 0.0000245, Time: 196.96
# New best model saved at iteration 52000 with test MSE: 0.0000241
# Iteration: 52000, Train loss: 0.0000241, Test loss: 0.0000241, Best test loss: 0.0000241, Time: 200.75
# Iteration: 53000, Train loss: 0.0000247, Test loss: 0.0000247, Best test loss: 0.0000241, Time: 204.98
# New best model saved at iteration 54000 with test MSE: 0.0000240
# Iteration: 54000, Train loss: 0.0000240, Test loss: 0.0000240, Best test loss: 0.0000240, Time: 210.17
# Iteration: 55000, Train loss: 0.0000256, Test loss: 0.0000256, Best test loss: 0.0000240, Time: 215.27
# Iteration: 56000, Train loss: 0.0000242, Test loss: 0.0000242, Best test loss: 0.0000240, Time: 220.39
# New best model saved at iteration 57000 with test MSE: 0.0000239
# Iteration: 57000, Train loss: 0.0000239, Test loss: 0.0000239, Best test loss: 0.0000239, Time: 224.39
# New best model saved at iteration 58000 with test MSE: 0.0000234
# Iteration: 58000, Train loss: 0.0000234, Test loss: 0.0000234, Best test loss: 0.0000234, Time: 228.08
# Iteration: 59000, Train loss: 0.0000263, Test loss: 0.0000263, Best test loss: 0.0000234, Time: 231.79
# Iteration: 60000, Train loss: 0.0000244, Test loss: 0.0000244, Best test loss: 0.0000234, Time: 235.64
# New best model saved at iteration 61000 with test MSE: 0.0000230
# Iteration: 61000, Train loss: 0.0000230, Test loss: 0.0000230, Best test loss: 0.0000230, Time: 239.38
# New best model saved at iteration 62000 with test MSE: 0.0000229
# Iteration: 62000, Train loss: 0.0000229, Test loss: 0.0000229, Best test loss: 0.0000229, Time: 243.13
# New best model saved at iteration 63000 with test MSE: 0.0000228
# Iteration: 63000, Train loss: 0.0000228, Test loss: 0.0000228, Best test loss: 0.0000228, Time: 246.82
# New best model saved at iteration 64000 with test MSE: 0.0000227
# Iteration: 64000, Train loss: 0.0000227, Test loss: 0.0000227, Best test loss: 0.0000227, Time: 250.46
# Iteration: 65000, Train loss: 0.0000230, Test loss: 0.0000230, Best test loss: 0.0000227, Time: 254.13
# Iteration: 66000, Train loss: 0.0000233, Test loss: 0.0000233, Best test loss: 0.0000227, Time: 257.84
# Iteration: 67000, Train loss: 0.0000258, Test loss: 0.0000258, Best test loss: 0.0000227, Time: 261.55
# New best model saved at iteration 68000 with test MSE: 0.0000222
# Iteration: 68000, Train loss: 0.0000222, Test loss: 0.0000222, Best test loss: 0.0000222, Time: 265.26
# New best model saved at iteration 69000 with test MSE: 0.0000220
# Iteration: 69000, Train loss: 0.0000220, Test loss: 0.0000220, Best test loss: 0.0000220, Time: 268.93
# Iteration: 70000, Train loss: 0.0000227, Test loss: 0.0000227, Best test loss: 0.0000220, Time: 272.53
# Iteration: 71000, Train loss: 0.0000222, Test loss: 0.0000222, Best test loss: 0.0000220, Time: 276.15
# Iteration: 72000, Train loss: 0.0000226, Test loss: 0.0000226, Best test loss: 0.0000220, Time: 279.82
# Iteration: 73000, Train loss: 0.0000224, Test loss: 0.0000224, Best test loss: 0.0000220, Time: 283.50
# New best model saved at iteration 74000 with test MSE: 0.0000213
# Iteration: 74000, Train loss: 0.0000213, Test loss: 0.0000213, Best test loss: 0.0000213, Time: 287.20
# New best model saved at iteration 75000 with test MSE: 0.0000211
# Iteration: 75000, Train loss: 0.0000211, Test loss: 0.0000211, Best test loss: 0.0000211, Time: 290.91
# Iteration: 76000, Train loss: 0.0000212, Test loss: 0.0000212, Best test loss: 0.0000211, Time: 294.71
# Iteration: 77000, Train loss: 0.0000230, Test loss: 0.0000230, Best test loss: 0.0000211, Time: 298.55
# Iteration: 78000, Train loss: 0.0000216, Test loss: 0.0000216, Best test loss: 0.0000211, Time: 302.40
# New best model saved at iteration 79000 with test MSE: 0.0000210
# Iteration: 79000, Train loss: 0.0000210, Test loss: 0.0000210, Best test loss: 0.0000210, Time: 306.30
# New best model saved at iteration 80000 with test MSE: 0.0000199
# Iteration: 80000, Train loss: 0.0000199, Test loss: 0.0000199, Best test loss: 0.0000199, Time: 310.19
# New best model saved at iteration 81000 with test MSE: 0.0000195
# Iteration: 81000, Train loss: 0.0000195, Test loss: 0.0000195, Best test loss: 0.0000195, Time: 314.02
# New best model saved at iteration 82000 with test MSE: 0.0000191
# Iteration: 82000, Train loss: 0.0000191, Test loss: 0.0000191, Best test loss: 0.0000191, Time: 317.75
# Iteration: 83000, Train loss: 0.0000196, Test loss: 0.0000196, Best test loss: 0.0000191, Time: 321.50
# New best model saved at iteration 84000 with test MSE: 0.0000186
# Iteration: 84000, Train loss: 0.0000186, Test loss: 0.0000186, Best test loss: 0.0000186, Time: 325.24
# Iteration: 85000, Train loss: 0.0000199, Test loss: 0.0000199, Best test loss: 0.0000186, Time: 328.93
# New best model saved at iteration 86000 with test MSE: 0.0000181
# Iteration: 86000, Train loss: 0.0000181, Test loss: 0.0000181, Best test loss: 0.0000181, Time: 332.61
# New best model saved at iteration 87000 with test MSE: 0.0000170
# Iteration: 87000, Train loss: 0.0000170, Test loss: 0.0000170, Best test loss: 0.0000170, Time: 336.30
# New best model saved at iteration 88000 with test MSE: 0.0000166
# Iteration: 88000, Train loss: 0.0000166, Test loss: 0.0000166, Best test loss: 0.0000166, Time: 340.04
# New best model saved at iteration 89000 with test MSE: 0.0000161
# Iteration: 89000, Train loss: 0.0000161, Test loss: 0.0000161, Best test loss: 0.0000161, Time: 343.77
# Iteration: 90000, Train loss: 0.0000163, Test loss: 0.0000163, Best test loss: 0.0000161, Time: 347.47
# New best model saved at iteration 91000 with test MSE: 0.0000158
# Iteration: 91000, Train loss: 0.0000158, Test loss: 0.0000158, Best test loss: 0.0000158, Time: 351.20
# New best model saved at iteration 92000 with test MSE: 0.0000154
# Iteration: 92000, Train loss: 0.0000154, Test loss: 0.0000154, Best test loss: 0.0000154, Time: 354.92
# Iteration: 93000, Train loss: 0.0000161, Test loss: 0.0000161, Best test loss: 0.0000154, Time: 358.61
# New best model saved at iteration 94000 with test MSE: 0.0000154
# Iteration: 94000, Train loss: 0.0000154, Test loss: 0.0000154, Best test loss: 0.0000154, Time: 362.31
# New best model saved at iteration 95000 with test MSE: 0.0000148
# Iteration: 95000, Train loss: 0.0000148, Test loss: 0.0000148, Best test loss: 0.0000148, Time: 365.99
# New best model saved at iteration 96000 with test MSE: 0.0000146
# Iteration: 96000, Train loss: 0.0000146, Test loss: 0.0000146, Best test loss: 0.0000146, Time: 369.68
# New best model saved at iteration 97000 with test MSE: 0.0000145
# Iteration: 97000, Train loss: 0.0000145, Test loss: 0.0000145, Best test loss: 0.0000145, Time: 373.39
# Iteration: 98000, Train loss: 0.0000148, Test loss: 0.0000148, Best test loss: 0.0000145, Time: 377.09
# New best model saved at iteration 99000 with test MSE: 0.0000142
# Iteration: 99000, Train loss: 0.0000142, Test loss: 0.0000142, Best test loss: 0.0000142, Time: 380.78
# Iteration: 100000, Train loss: 0.0000145, Test loss: 0.0000145, Best test loss: 0.0000142, Time: 384.51
# Iteration: 101000, Train loss: 0.0000150, Test loss: 0.0000150, Best test loss: 0.0000142, Time: 388.42
# New best model saved at iteration 102000 with test MSE: 0.0000134
# Iteration: 102000, Train loss: 0.0000134, Test loss: 0.0000134, Best test loss: 0.0000134, Time: 392.31
# Iteration: 103000, Train loss: 0.0000134, Test loss: 0.0000134, Best test loss: 0.0000134, Time: 397.26
# New best model saved at iteration 104000 with test MSE: 0.0000129
# Iteration: 104000, Train loss: 0.0000129, Test loss: 0.0000129, Best test loss: 0.0000129, Time: 402.50
# Iteration: 105000, Train loss: 0.0000130, Test loss: 0.0000130, Best test loss: 0.0000129, Time: 407.61
# Iteration: 106000, Train loss: 0.0000130, Test loss: 0.0000130, Best test loss: 0.0000129, Time: 412.38
# New best model saved at iteration 107000 with test MSE: 0.0000118
# Iteration: 107000, Train loss: 0.0000118, Test loss: 0.0000118, Best test loss: 0.0000118, Time: 416.16
# New best model saved at iteration 108000 with test MSE: 0.0000116
# Iteration: 108000, Train loss: 0.0000116, Test loss: 0.0000116, Best test loss: 0.0000116, Time: 419.93
# New best model saved at iteration 109000 with test MSE: 0.0000111
# Iteration: 109000, Train loss: 0.0000111, Test loss: 0.0000111, Best test loss: 0.0000111, Time: 423.70
# New best model saved at iteration 110000 with test MSE: 0.0000109
# Iteration: 110000, Train loss: 0.0000109, Test loss: 0.0000109, Best test loss: 0.0000109, Time: 427.45
# New best model saved at iteration 111000 with test MSE: 0.0000106
# Iteration: 111000, Train loss: 0.0000106, Test loss: 0.0000106, Best test loss: 0.0000106, Time: 431.23
# New best model saved at iteration 112000 with test MSE: 0.0000102
# Iteration: 112000, Train loss: 0.0000102, Test loss: 0.0000102, Best test loss: 0.0000102, Time: 435.01
# New best model saved at iteration 113000 with test MSE: 0.0000100
# Iteration: 113000, Train loss: 0.0000100, Test loss: 0.0000100, Best test loss: 0.0000100, Time: 438.78
# New best model saved at iteration 114000 with test MSE: 0.0000100
# Iteration: 114000, Train loss: 0.0000100, Test loss: 0.0000100, Best test loss: 0.0000100, Time: 442.52
# New best model saved at iteration 115000 with test MSE: 0.0000096
# Iteration: 115000, Train loss: 0.0000096, Test loss: 0.0000096, Best test loss: 0.0000096, Time: 446.24
# New best model saved at iteration 116000 with test MSE: 0.0000093
# Iteration: 116000, Train loss: 0.0000093, Test loss: 0.0000093, Best test loss: 0.0000093, Time: 449.96
# Iteration: 117000, Train loss: 0.0000101, Test loss: 0.0000101, Best test loss: 0.0000093, Time: 453.66
# New best model saved at iteration 118000 with test MSE: 0.0000090
# Iteration: 118000, Train loss: 0.0000090, Test loss: 0.0000090, Best test loss: 0.0000090, Time: 457.39
# New best model saved at iteration 119000 with test MSE: 0.0000089
# Iteration: 119000, Train loss: 0.0000089, Test loss: 0.0000089, Best test loss: 0.0000089, Time: 461.16
# New best model saved at iteration 120000 with test MSE: 0.0000087
# Iteration: 120000, Train loss: 0.0000087, Test loss: 0.0000087, Best test loss: 0.0000087, Time: 464.92
# New best model saved at iteration 121000 with test MSE: 0.0000087
# Iteration: 121000, Train loss: 0.0000087, Test loss: 0.0000087, Best test loss: 0.0000087, Time: 468.69
# Iteration: 122000, Train loss: 0.0000092, Test loss: 0.0000092, Best test loss: 0.0000087, Time: 472.39
# Iteration: 123000, Train loss: 0.0000091, Test loss: 0.0000091, Best test loss: 0.0000087, Time: 476.11
# New best model saved at iteration 124000 with test MSE: 0.0000085
# Iteration: 124000, Train loss: 0.0000085, Test loss: 0.0000085, Best test loss: 0.0000085, Time: 479.83
# New best model saved at iteration 125000 with test MSE: 0.0000082
# Iteration: 125000, Train loss: 0.0000082, Test loss: 0.0000082, Best test loss: 0.0000082, Time: 483.58
# Iteration: 126000, Train loss: 0.0000098, Test loss: 0.0000098, Best test loss: 0.0000082, Time: 487.29
# Iteration: 127000, Train loss: 0.0000082, Test loss: 0.0000082, Best test loss: 0.0000082, Time: 491.02
# New best model saved at iteration 128000 with test MSE: 0.0000081
# Iteration: 128000, Train loss: 0.0000081, Test loss: 0.0000081, Best test loss: 0.0000081, Time: 494.74
# New best model saved at iteration 129000 with test MSE: 0.0000079
# Iteration: 129000, Train loss: 0.0000079, Test loss: 0.0000079, Best test loss: 0.0000079, Time: 498.46
# New best model saved at iteration 130000 with test MSE: 0.0000077
# Iteration: 130000, Train loss: 0.0000077, Test loss: 0.0000077, Best test loss: 0.0000077, Time: 502.18
# New best model saved at iteration 131000 with test MSE: 0.0000077
# Iteration: 131000, Train loss: 0.0000077, Test loss: 0.0000077, Best test loss: 0.0000077, Time: 505.93
# New best model saved at iteration 132000 with test MSE: 0.0000075
# Iteration: 132000, Train loss: 0.0000075, Test loss: 0.0000075, Best test loss: 0.0000075, Time: 509.68
# Iteration: 133000, Train loss: 0.0000075, Test loss: 0.0000075, Best test loss: 0.0000075, Time: 513.47
# New best model saved at iteration 134000 with test MSE: 0.0000073
# Iteration: 134000, Train loss: 0.0000073, Test loss: 0.0000073, Best test loss: 0.0000073, Time: 517.22
# Iteration: 135000, Train loss: 0.0000077, Test loss: 0.0000077, Best test loss: 0.0000073, Time: 520.97
# New best model saved at iteration 136000 with test MSE: 0.0000071
# Iteration: 136000, Train loss: 0.0000071, Test loss: 0.0000071, Best test loss: 0.0000071, Time: 524.73
# Iteration: 137000, Train loss: 0.0000072, Test loss: 0.0000072, Best test loss: 0.0000071, Time: 528.47
# Iteration: 138000, Train loss: 0.0000075, Test loss: 0.0000075, Best test loss: 0.0000071, Time: 532.18
# New best model saved at iteration 139000 with test MSE: 0.0000068
# Iteration: 139000, Train loss: 0.0000068, Test loss: 0.0000068, Best test loss: 0.0000068, Time: 535.87
# Iteration: 140000, Train loss: 0.0000071, Test loss: 0.0000071, Best test loss: 0.0000068, Time: 539.59
# New best model saved at iteration 141000 with test MSE: 0.0000066
# Iteration: 141000, Train loss: 0.0000066, Test loss: 0.0000066, Best test loss: 0.0000066, Time: 543.25
# Iteration: 142000, Train loss: 0.0000086, Test loss: 0.0000086, Best test loss: 0.0000066, Time: 546.88
# New best model saved at iteration 143000 with test MSE: 0.0000065
# Iteration: 143000, Train loss: 0.0000065, Test loss: 0.0000065, Best test loss: 0.0000065, Time: 550.52
# Iteration: 144000, Train loss: 0.0000066, Test loss: 0.0000066, Best test loss: 0.0000065, Time: 554.15
# Iteration: 145000, Train loss: 0.0000065, Test loss: 0.0000065, Best test loss: 0.0000065, Time: 557.80
# Iteration: 146000, Train loss: 0.0000066, Test loss: 0.0000066, Best test loss: 0.0000065, Time: 561.49
# Iteration: 147000, Train loss: 0.0000065, Test loss: 0.0000065, Best test loss: 0.0000065, Time: 565.40
# Iteration: 148000, Train loss: 0.0000066, Test loss: 0.0000066, Best test loss: 0.0000065, Time: 569.06
# New best model saved at iteration 149000 with test MSE: 0.0000058
# Iteration: 149000, Train loss: 0.0000058, Test loss: 0.0000058, Best test loss: 0.0000058, Time: 572.73
# New best model saved at iteration 150000 with test MSE: 0.0000057
# Iteration: 150000, Train loss: 0.0000057, Test loss: 0.0000057, Best test loss: 0.0000057, Time: 576.65
# Iteration: 151000, Train loss: 0.0000059, Test loss: 0.0000059, Best test loss: 0.0000057, Time: 580.51
# New best model saved at iteration 152000 with test MSE: 0.0000057
# Iteration: 152000, Train loss: 0.0000057, Test loss: 0.0000057, Best test loss: 0.0000057, Time: 584.86
# New best model saved at iteration 153000 with test MSE: 0.0000056
# Iteration: 153000, Train loss: 0.0000056, Test loss: 0.0000056, Best test loss: 0.0000056, Time: 590.16
# Iteration: 154000, Train loss: 0.0000058, Test loss: 0.0000058, Best test loss: 0.0000056, Time: 595.27
# New best model saved at iteration 155000 with test MSE: 0.0000055
# Iteration: 155000, Train loss: 0.0000055, Test loss: 0.0000055, Best test loss: 0.0000055, Time: 600.30
# Iteration: 156000, Train loss: 0.0000060, Test loss: 0.0000060, Best test loss: 0.0000055, Time: 604.53
# New best model saved at iteration 157000 with test MSE: 0.0000054
# Iteration: 157000, Train loss: 0.0000054, Test loss: 0.0000054, Best test loss: 0.0000054, Time: 608.24
# Iteration: 158000, Train loss: 0.0000059, Test loss: 0.0000059, Best test loss: 0.0000054, Time: 611.93
# Iteration: 159000, Train loss: 0.0000055, Test loss: 0.0000055, Best test loss: 0.0000054, Time: 615.62
# Iteration: 160000, Train loss: 0.0000059, Test loss: 0.0000059, Best test loss: 0.0000054, Time: 619.35
# New best model saved at iteration 161000 with test MSE: 0.0000052
# Iteration: 161000, Train loss: 0.0000052, Test loss: 0.0000052, Best test loss: 0.0000052, Time: 623.11
# Iteration: 162000, Train loss: 0.0000053, Test loss: 0.0000053, Best test loss: 0.0000052, Time: 626.86
# Iteration: 163000, Train loss: 0.0000055, Test loss: 0.0000055, Best test loss: 0.0000052, Time: 630.63
# Iteration: 164000, Train loss: 0.0000053, Test loss: 0.0000053, Best test loss: 0.0000052, Time: 634.36
# New best model saved at iteration 165000 with test MSE: 0.0000050
# Iteration: 165000, Train loss: 0.0000050, Test loss: 0.0000050, Best test loss: 0.0000050, Time: 638.07
# New best model saved at iteration 166000 with test MSE: 0.0000049
# Iteration: 166000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000049, Time: 641.79
# Iteration: 167000, Train loss: 0.0000052, Test loss: 0.0000052, Best test loss: 0.0000049, Time: 645.48
# Iteration: 168000, Train loss: 0.0000050, Test loss: 0.0000050, Best test loss: 0.0000049, Time: 649.20
# Iteration: 169000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000049, Time: 652.92
# Iteration: 170000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000049, Time: 656.69
# New best model saved at iteration 171000 with test MSE: 0.0000048
# Iteration: 171000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000048, Time: 660.45
# Iteration: 172000, Train loss: 0.0000056, Test loss: 0.0000056, Best test loss: 0.0000048, Time: 664.24
# Iteration: 173000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000048, Time: 668.00
# New best model saved at iteration 174000 with test MSE: 0.0000048
# Iteration: 174000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000048, Time: 671.78
# New best model saved at iteration 175000 with test MSE: 0.0000047
# Iteration: 175000, Train loss: 0.0000047, Test loss: 0.0000047, Best test loss: 0.0000047, Time: 675.54
# New best model saved at iteration 176000 with test MSE: 0.0000046
# Iteration: 176000, Train loss: 0.0000046, Test loss: 0.0000046, Best test loss: 0.0000046, Time: 679.30
# Iteration: 177000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000046, Time: 683.04
# Iteration: 178000, Train loss: 0.0000047, Test loss: 0.0000047, Best test loss: 0.0000046, Time: 686.78
# Iteration: 179000, Train loss: 0.0000052, Test loss: 0.0000052, Best test loss: 0.0000046, Time: 690.52
# New best model saved at iteration 180000 with test MSE: 0.0000046
# Iteration: 180000, Train loss: 0.0000046, Test loss: 0.0000046, Best test loss: 0.0000046, Time: 694.28
# Iteration: 181000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000046, Time: 698.04
# Iteration: 182000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000046, Time: 701.79
# New best model saved at iteration 183000 with test MSE: 0.0000045
# Iteration: 183000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000045, Time: 705.55
# Iteration: 184000, Train loss: 0.0000049, Test loss: 0.0000049, Best test loss: 0.0000045, Time: 709.31
# Iteration: 185000, Train loss: 0.0000046, Test loss: 0.0000046, Best test loss: 0.0000045, Time: 713.07
# Iteration: 186000, Train loss: 0.0000046, Test loss: 0.0000046, Best test loss: 0.0000045, Time: 716.77
# New best model saved at iteration 187000 with test MSE: 0.0000044
# Iteration: 187000, Train loss: 0.0000044, Test loss: 0.0000044, Best test loss: 0.0000044, Time: 720.46
# Iteration: 188000, Train loss: 0.0000064, Test loss: 0.0000064, Best test loss: 0.0000044, Time: 724.18
# Iteration: 189000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000044, Time: 727.92
# New best model saved at iteration 190000 with test MSE: 0.0000043
# Iteration: 190000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000043, Time: 731.62
# New best model saved at iteration 191000 with test MSE: 0.0000043
# Iteration: 191000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000043, Time: 735.36
# Iteration: 192000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000043, Time: 739.09
# Iteration: 193000, Train loss: 0.0000047, Test loss: 0.0000047, Best test loss: 0.0000043, Time: 742.79
# Iteration: 194000, Train loss: 0.0000044, Test loss: 0.0000044, Best test loss: 0.0000043, Time: 746.46
# New best model saved at iteration 195000 with test MSE: 0.0000043
# Iteration: 195000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000043, Time: 750.16
# New best model saved at iteration 196000 with test MSE: 0.0000042
# Iteration: 196000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000042, Time: 753.91
# Iteration: 197000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000042, Time: 757.66
# New best model saved at iteration 198000 with test MSE: 0.0000041
# Iteration: 198000, Train loss: 0.0000041, Test loss: 0.0000041, Best test loss: 0.0000041, Time: 761.42
# Iteration: 199000, Train loss: 0.0000051, Test loss: 0.0000051, Best test loss: 0.0000041, Time: 765.15
# New best model saved at iteration 200000 with test MSE: 0.0000041
# Iteration: 200000, Train loss: 0.0000041, Test loss: 0.0000041, Best test loss: 0.0000041, Time: 768.88
# Iteration: 201000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000041, Time: 772.56
# Iteration: 202000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000041, Time: 776.47
# Iteration: 203000, Train loss: 0.0000044, Test loss: 0.0000044, Best test loss: 0.0000041, Time: 780.73
# New best model saved at iteration 204000 with test MSE: 0.0000041
# Iteration: 204000, Train loss: 0.0000041, Test loss: 0.0000041, Best test loss: 0.0000041, Time: 784.94
# Iteration: 205000, Train loss: 0.0000041, Test loss: 0.0000041, Best test loss: 0.0000041, Time: 789.07
# Iteration: 206000, Train loss: 0.0000047, Test loss: 0.0000047, Best test loss: 0.0000041, Time: 793.35
# New best model saved at iteration 207000 with test MSE: 0.0000040
# Iteration: 207000, Train loss: 0.0000040, Test loss: 0.0000040, Best test loss: 0.0000040, Time: 797.05
# Iteration: 208000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000040, Time: 800.73
# Iteration: 209000, Train loss: 0.0000041, Test loss: 0.0000041, Best test loss: 0.0000040, Time: 804.40
# New best model saved at iteration 210000 with test MSE: 0.0000039
# Iteration: 210000, Train loss: 0.0000039, Test loss: 0.0000039, Best test loss: 0.0000039, Time: 808.12
# Iteration: 211000, Train loss: 0.0000040, Test loss: 0.0000040, Best test loss: 0.0000039, Time: 811.80
# Iteration: 212000, Train loss: 0.0000039, Test loss: 0.0000039, Best test loss: 0.0000039, Time: 815.50
# New best model saved at iteration 213000 with test MSE: 0.0000038
# Iteration: 213000, Train loss: 0.0000038, Test loss: 0.0000038, Best test loss: 0.0000038, Time: 819.20
# New best model saved at iteration 214000 with test MSE: 0.0000037
# Iteration: 214000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000037, Time: 822.88
# New best model saved at iteration 215000 with test MSE: 0.0000035
# Iteration: 215000, Train loss: 0.0000035, Test loss: 0.0000035, Best test loss: 0.0000035, Time: 826.56
# Iteration: 216000, Train loss: 0.0000036, Test loss: 0.0000036, Best test loss: 0.0000035, Time: 830.21
# Iteration: 217000, Train loss: 0.0000040, Test loss: 0.0000040, Best test loss: 0.0000035, Time: 833.89
# Iteration: 218000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000035, Time: 837.55
# New best model saved at iteration 219000 with test MSE: 0.0000033
# Iteration: 219000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000033, Time: 841.28
# Iteration: 220000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000033, Time: 844.99
# Iteration: 221000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000033, Time: 848.66
# Iteration: 222000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000033, Time: 852.35
# New best model saved at iteration 223000 with test MSE: 0.0000031
# Iteration: 223000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000031, Time: 856.05
# New best model saved at iteration 224000 with test MSE: 0.0000031
# Iteration: 224000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000031, Time: 859.75
# New best model saved at iteration 225000 with test MSE: 0.0000031
# Iteration: 225000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000031, Time: 863.44
# New best model saved at iteration 226000 with test MSE: 0.0000030
# Iteration: 226000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000030, Time: 867.13
# Iteration: 227000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000030, Time: 870.81
# New best model saved at iteration 228000 with test MSE: 0.0000028
# Iteration: 228000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000028, Time: 874.55
# Iteration: 229000, Train loss: 0.0000035, Test loss: 0.0000035, Best test loss: 0.0000028, Time: 878.29
# Iteration: 230000, Train loss: 0.0000029, Test loss: 0.0000029, Best test loss: 0.0000028, Time: 882.04
# New best model saved at iteration 231000 with test MSE: 0.0000026
# Iteration: 231000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000026, Time: 885.76
# Iteration: 232000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000026, Time: 889.59
# New best model saved at iteration 233000 with test MSE: 0.0000026
# Iteration: 233000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000026, Time: 893.44
# Iteration: 234000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000026, Time: 897.29
# Iteration: 235000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000026, Time: 901.16
# Iteration: 236000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000026, Time: 904.98
# Iteration: 237000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000026, Time: 908.80
# New best model saved at iteration 238000 with test MSE: 0.0000026
# Iteration: 238000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000026, Time: 912.68
# Iteration: 239000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000026, Time: 916.53
# New best model saved at iteration 240000 with test MSE: 0.0000025
# Iteration: 240000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000025, Time: 920.32
# New best model saved at iteration 241000 with test MSE: 0.0000025
# Iteration: 241000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000025, Time: 924.11
# Iteration: 242000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000025, Time: 927.93
# Iteration: 243000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000025, Time: 931.76
# Iteration: 244000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000025, Time: 935.60
# New best model saved at iteration 245000 with test MSE: 0.0000024
# Iteration: 245000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 939.42
# Iteration: 246000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000024, Time: 943.22
# Iteration: 247000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000024, Time: 947.03
# Iteration: 248000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 950.82
# New best model saved at iteration 249000 with test MSE: 0.0000024
# Iteration: 249000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 954.60
# Iteration: 250000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 958.37
# Iteration: 251000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 962.01
# Iteration: 252000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000024, Time: 965.66
# Iteration: 253000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000024, Time: 969.71
# Iteration: 254000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 973.79
# Iteration: 255000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 978.19
# Iteration: 256000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 982.21
# Iteration: 257000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 985.98
# Iteration: 258000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000024, Time: 989.70
# New best model saved at iteration 259000 with test MSE: 0.0000023
# Iteration: 259000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000023, Time: 993.38
# Iteration: 260000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000023, Time: 997.04
# New best model saved at iteration 261000 with test MSE: 0.0000023
# Iteration: 261000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000023, Time: 1000.69
# Iteration: 262000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000023, Time: 1004.34
# Iteration: 263000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000023, Time: 1007.99
# Iteration: 264000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000023, Time: 1011.63
# Iteration: 265000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000023, Time: 1015.28
# Iteration: 266000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000023, Time: 1018.95
# New best model saved at iteration 267000 with test MSE: 0.0000022
# Iteration: 267000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000022, Time: 1022.60
# Iteration: 268000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000022, Time: 1026.26
# Iteration: 269000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000022, Time: 1029.92
# Iteration: 270000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000022, Time: 1033.61
# Iteration: 271000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000022, Time: 1037.29
# Iteration: 272000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000022, Time: 1041.00
# Iteration: 273000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000022, Time: 1044.68
# Iteration: 274000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000022, Time: 1048.36
# New best model saved at iteration 275000 with test MSE: 0.0000022
# Iteration: 275000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000022, Time: 1052.05
# Iteration: 276000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000022, Time: 1055.72
# Iteration: 277000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000022, Time: 1059.40
# Iteration: 278000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000022, Time: 1063.06
# Iteration: 279000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000022, Time: 1066.73
# New best model saved at iteration 280000 with test MSE: 0.0000021
# Iteration: 280000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1070.44
# Iteration: 281000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000021, Time: 1074.13
# Iteration: 282000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000021, Time: 1077.81
# Iteration: 283000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1081.54
# Iteration: 284000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000021, Time: 1085.30
# Iteration: 285000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000021, Time: 1089.08
# New best model saved at iteration 286000 with test MSE: 0.0000021
# Iteration: 286000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1092.82
# Iteration: 287000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000021, Time: 1096.56
# Iteration: 288000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000021, Time: 1100.27
# New best model saved at iteration 289000 with test MSE: 0.0000021
# Iteration: 289000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1103.98
# Iteration: 290000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000021, Time: 1107.70
# Iteration: 291000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1111.45
# Iteration: 292000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000021, Time: 1115.17
# Iteration: 293000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1118.88
# Iteration: 294000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1122.61
# New best model saved at iteration 295000 with test MSE: 0.0000021
# Iteration: 295000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 1126.39
# New best model saved at iteration 296000 with test MSE: 0.0000020
# Iteration: 296000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000020, Time: 1130.14
# Iteration: 297000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000020, Time: 1133.90
# New best model saved at iteration 298000 with test MSE: 0.0000020
# Iteration: 298000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000020, Time: 1137.65
# Iteration: 299000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000020, Time: 1141.36
# New best model saved at iteration 300000 with test MSE: 0.0000020
# Iteration: 300000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000020, Time: 1145.13
# Iteration: 301000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000020, Time: 1148.89
# Iteration: 302000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000020, Time: 1152.74
# Iteration: 303000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000020, Time: 1156.94
# Iteration: 304000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000020, Time: 1161.13
# Iteration: 305000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000020, Time: 1165.32
# Iteration: 306000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000020, Time: 1169.45
# Iteration: 307000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000020, Time: 1173.25
# Iteration: 308000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000020, Time: 1177.05
# Iteration: 309000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000020, Time: 1180.86
# Iteration: 310000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000020, Time: 1184.64
# Iteration: 311000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000020, Time: 1188.41
# Iteration: 312000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000020, Time: 1192.18
# Iteration: 313000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000020, Time: 1195.97
# New best model saved at iteration 314000 with test MSE: 0.0000019
# Iteration: 314000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1199.76
# Iteration: 315000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000019, Time: 1203.54
# Iteration: 316000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1207.29
# Iteration: 317000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000019, Time: 1211.04
# Iteration: 318000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1214.75
# Iteration: 319000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000019, Time: 1218.50
# New best model saved at iteration 320000 with test MSE: 0.0000019
# Iteration: 320000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1222.29
# Iteration: 321000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1226.07
# Iteration: 322000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1229.80
# Iteration: 323000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1233.56
# Iteration: 324000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1237.33
# Iteration: 325000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1241.07
# Iteration: 326000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1244.83
# Iteration: 327000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1248.60
# Iteration: 328000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1252.39
# Iteration: 329000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000019, Time: 1256.17
# New best model saved at iteration 330000 with test MSE: 0.0000019
# Iteration: 330000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1259.96
# Iteration: 331000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1263.73
# Iteration: 332000, Train loss: 0.0000032, Test loss: 0.0000032, Best test loss: 0.0000019, Time: 1267.49
# Iteration: 333000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000019, Time: 1271.22
# Iteration: 334000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000019, Time: 1274.94
# Iteration: 335000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000019, Time: 1278.67
# New best model saved at iteration 336000 with test MSE: 0.0000018
# Iteration: 336000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000018, Time: 1282.43
# Iteration: 337000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000018, Time: 1286.15
# Iteration: 338000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000018, Time: 1289.90
# New best model saved at iteration 339000 with test MSE: 0.0000017
# Iteration: 339000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 1293.68
# Iteration: 340000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 1297.42
# Iteration: 341000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000017, Time: 1301.19
# New best model saved at iteration 342000 with test MSE: 0.0000017
# Iteration: 342000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 1304.93
# Iteration: 343000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000017, Time: 1308.69
# Iteration: 344000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 1312.44
# Iteration: 345000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000017, Time: 1316.20
# New best model saved at iteration 346000 with test MSE: 0.0000017
# Iteration: 346000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 1319.89
# New best model saved at iteration 347000 with test MSE: 0.0000016
# Iteration: 347000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000016, Time: 1323.61
# Iteration: 348000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000016, Time: 1327.34
# New best model saved at iteration 349000 with test MSE: 0.0000015
# Iteration: 349000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000015, Time: 1331.11
# Iteration: 350000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000015, Time: 1334.85
# Iteration: 351000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000015, Time: 1338.80
# New best model saved at iteration 352000 with test MSE: 0.0000014
# Iteration: 352000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000014, Time: 1343.02
# New best model saved at iteration 353000 with test MSE: 0.0000013
# Iteration: 353000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000013, Time: 1347.27
# Iteration: 354000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000013, Time: 1351.41
# Iteration: 355000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000013, Time: 1355.48
# Iteration: 356000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000013, Time: 1359.21
# New best model saved at iteration 357000 with test MSE: 0.0000013
# Iteration: 357000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000013, Time: 1362.95
# ...
# New best model saved at iteration 855000 with test MSE: 0.0000005
# Iteration: 855000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3262.13
# Iteration: 856000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3265.87
# Iteration: 857000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 3269.64
# Iteration: 858000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3273.42
# New best model saved at iteration 859000 with test MSE: 0.0000005
# Iteration: 859000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3277.21
# Iteration: 860000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3281.00
# Iteration: 861000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3284.77
# Iteration: 862000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3288.56
# Iteration: 863000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3292.35
# Iteration: 864000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3296.16
# Iteration: 865000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3299.94
# Iteration: 866000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3303.71
# Iteration: 867000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3307.48
# Iteration: 868000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3311.25
# Iteration: 869000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3315.04
# Iteration: 870000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3318.82
# Iteration: 871000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 3322.56
# Iteration: 872000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3326.30
# Iteration: 873000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3330.07
# Iteration: 874000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000005, Time: 3333.83
# Iteration: 875000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3337.62
# Iteration: 876000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3341.44
# Iteration: 877000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3345.25
# Iteration: 878000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3349.04
# Iteration: 879000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3352.81
# Iteration: 880000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3356.58
# Iteration: 881000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3360.33
# New best model saved at iteration 882000 with test MSE: 0.0000005
# Iteration: 882000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3364.06
# Iteration: 883000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3367.78
# Iteration: 884000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3371.50
# Iteration: 885000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3375.21
# Iteration: 886000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3378.91
# Iteration: 887000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3382.65
# Iteration: 888000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3386.43
# Iteration: 889000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3390.22
# Iteration: 890000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3394.16
# Iteration: 891000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3398.43
# Iteration: 892000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3402.71
# Iteration: 893000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3407.05
# Iteration: 894000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3411.27
# Iteration: 895000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3415.04
# Iteration: 896000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3418.81
# Iteration: 897000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3422.57
# Iteration: 898000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3426.29
# Iteration: 899000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3430.04
# Iteration: 900000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3433.83
# Iteration: 901000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3437.61
# Iteration: 902000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3441.43
# Iteration: 903000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3445.21
# Iteration: 904000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3449.01
# Iteration: 905000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3452.86
# Iteration: 906000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3456.71
# Iteration: 907000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3460.57
# Iteration: 908000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3464.41
# Iteration: 909000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3468.23
# New best model saved at iteration 910000 with test MSE: 0.0000005
# Iteration: 910000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3472.00
# Iteration: 911000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3475.77
# Iteration: 912000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3479.52
# Iteration: 913000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3483.22
# Iteration: 914000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3486.90
# Iteration: 915000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3490.64
# Iteration: 916000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3494.45
# Iteration: 917000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3498.28
# Iteration: 918000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3502.09
# Iteration: 919000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3505.91
# Iteration: 920000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3509.75
# New best model saved at iteration 921000 with test MSE: 0.0000005
# Iteration: 921000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3513.60
# Iteration: 922000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3517.43
# Iteration: 923000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3521.21
# Iteration: 924000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3524.96
# Iteration: 925000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3528.74
# Iteration: 926000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3532.53
# Iteration: 927000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3536.31
# Iteration: 928000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3540.09
# Iteration: 929000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3543.86
# New best model saved at iteration 930000 with test MSE: 0.0000005
# Iteration: 930000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3547.66
# Iteration: 931000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3551.43
# Iteration: 932000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3555.18
# Iteration: 933000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3558.96
# Iteration: 934000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3562.75
# New best model saved at iteration 935000 with test MSE: 0.0000005
# Iteration: 935000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3566.56
# Iteration: 936000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3570.34
# New best model saved at iteration 937000 with test MSE: 0.0000005
# Iteration: 937000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3574.12
# Iteration: 938000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3577.87
# Iteration: 939000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3581.88
# Iteration: 940000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3586.11
# Iteration: 941000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3590.37
# Iteration: 942000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3594.61
# Iteration: 943000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3598.85
# New best model saved at iteration 944000 with test MSE: 0.0000005
# Iteration: 944000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3602.69
# Iteration: 945000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3606.54
# Iteration: 946000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3610.37
# Iteration: 947000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3614.16
# Iteration: 948000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3617.96
# Iteration: 949000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3621.81
# Iteration: 950000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3625.69
# Iteration: 951000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3629.55
# Iteration: 952000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3633.40
# Iteration: 953000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3637.26
# Iteration: 954000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3641.09
# Iteration: 955000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3644.93
# Iteration: 956000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3648.75
# Iteration: 957000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3652.54
# Iteration: 958000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3656.33
# Iteration: 959000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3660.15
# Iteration: 960000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3663.95
# New best model saved at iteration 961000 with test MSE: 0.0000005
# Iteration: 961000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3667.78
# Iteration: 962000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3671.61
# Iteration: 963000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3675.46
# Iteration: 964000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3679.32
# Iteration: 965000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3683.16
# Iteration: 966000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000005, Time: 3687.01
# Iteration: 967000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3690.85
# Iteration: 968000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3694.67
# Iteration: 969000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3698.48
# Iteration: 970000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3702.29
# Iteration: 971000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3706.08
# Iteration: 972000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3709.87
# Iteration: 973000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3713.65
# New best model saved at iteration 974000 with test MSE: 0.0000005
# Iteration: 974000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3717.38
# Iteration: 975000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3721.14
# Iteration: 976000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3724.87
# Iteration: 977000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3728.61
# Iteration: 978000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3732.38
# Iteration: 979000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3736.17
# Iteration: 980000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3739.98
# Iteration: 981000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3743.80
# Iteration: 982000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3747.60
# Iteration: 983000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3751.37
# Iteration: 984000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3755.11
# Iteration: 985000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3758.84
# Iteration: 986000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3762.60
# Iteration: 987000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3766.36
# Iteration: 988000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3770.49
# Iteration: 989000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3774.78
# Iteration: 990000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3779.14
# Iteration: 991000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3783.51
# Iteration: 992000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3787.66
# Iteration: 993000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3791.51
# Iteration: 994000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3795.37
# Iteration: 995000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3799.20
# Iteration: 996000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3803.02
# Iteration: 997000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3806.82
# Iteration: 998000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3810.61
# Iteration: 999000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3814.40
# Time (sec) to complete:
# 3896.17835855484

# %%
# params_branch, params_trunk = params
# Load the best model parameters
best_params = load_model_params(resultdir, filename='model_params_best.pkl')
print("Loaded best model parameters")

# Predictions
mse_list = []

branch_inputs = inputs_test
trunk_inputs = grid
prediction = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval) 

save_dict = {'u_test': inputs_test.T, 'v_pred': prediction.T,\
             'v_target': outputs_test.T}

io.savemat(resultdir+'/pred.mat', save_dict)

for i in range(inputs_test.shape[0]):

    branch_inputs = inputs_test[i].reshape(1, nx) 
    trunk_inputs = grid # (neval, 1) 

    prediction_i = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval)
    target_i = outputs_test[i]

    mse_i = np.mean((prediction_i - target_i)**2)
    mse_list.append(mse_i.item())

    if i % 1000 == 0:
        print(colored('TEST SAMPLE '+str(i+1), 'red'))

        r2score = metrics.r2_score(target_i.flatten(), prediction_i.flatten())
        relerror = np.linalg.norm(target_i- prediction_i) / np.linalg.norm(target_i)
        r2score = float('%.4f'%r2score)
        relerror = float('%.4f'%relerror)
        print('Rel. L2 Error = '+str(relerror)+', R2 score = '+str(r2score))

        fig = plt.figure(figsize=(15, 4))

        # Adjust subplot parameters for better spacing
        plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.3)

        # Input plot
        ax = fig.add_subplot(1, 3, 1)
        plt.plot(inputs_test[i,0:-1])
        plt.title('Input', fontsize=14)

        # Output plot
        ax = fig.add_subplot(1, 3, 2)
        target = target_i.reshape(grid.shape[0])
        prediction = prediction_i.reshape(grid.shape[0])
        plt.plot(target, color='blue', linewidth=2)
        plt.plot(prediction, color='red', linewidth=2)
        plt.title('Output Field', fontsize=14)
        plt.legend(['Target', 'Prediction'])

        # Error plot
        ax = fig.add_subplot(1, 3, 3)
        error = target - prediction
        plt.plot(error, color='magenta')
        plt.yscale("log")  
        plt.title('Absolute Error', fontsize=14)

        print(colored('#'*230, 'green'))

mse = sum(mse_list) / len(mse_list)
print("Mean Squared Error Test :\n", mse)
# Out:
# Loaded best model parameters
# TEST SAMPLE 1
# Rel. L2 Error = 0.001, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 1001
# Rel. L2 Error = 0.0007, R2 score = 0.9999
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 2001
# Rel. L2 Error = 0.0007, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 3001
# Rel. L2 Error = 0.0006, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 4001
# Rel. L2 Error = 0.0006, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 5001
# Rel. L2 Error = 0.0006, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# Mean Squared Error Test :
#  3.4977415663542996e-07
