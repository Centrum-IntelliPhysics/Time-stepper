# %% [markdown]
# #### Designing a time-stepper model for Allen Cahn - Single Parameter

# %%
import jax.numpy as jnp
import numpy.random as npr
from jax import jit, grad, vmap
from jax.example_libraries.optimizers import adam
from jax import value_and_grad
from functools import partial
from jax import jacfwd, jacrev
import jax.nn as jnn
import math
from jax import random
import jax
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from flax import linen as nn
import sklearn.metrics

import argparse
import os
import time
from termcolor import colored
from scipy.io import loadmat
import scipy.io as io
import pickle

import sys
sys.path.append("../..")

import matplotlib
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 9})
import seaborn as sns
sns.set_style("white")
sns.set_style("ticks")

import warnings
warnings.filterwarnings("ignore")

# Check where gpu is enable or not
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# cpu

# %%
cluster = False
save = True

# %%
if cluster == True:
    parser = argparse.ArgumentParser()
    parser.add_argument('-seed', dest='seed', type=int, default=0, help='Seed number.')
    args = parser.parse_args()

    # Print all the arguments
    for arg in vars(args):
        print(f'{arg}: {getattr(args, arg)}')

    seed = args.seed

if cluster == False:
    seed = 0 # Seed number.

if save == True:
    resultdir = os.path.join(os.getcwd(), 'Results')
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

if save == True and cluster == True:
    orig_stdout = sys.stdout
    q = open(os.path.join(resultdir, 'outputs.txt'), 'w')
    sys.stdout = q
    print ("------START------")

print('seed = '+str(seed))
# Out:
# seed = 0

# %%
np.random.seed(seed)
key = 1234 #random.PRNGKey(seed)

# %%
data = loadmat('../data/singleparameter/data_single_parameter_022_AC_new_aligned_healing_shorter2.mat') # Load the .mat file
# print(data)
print(data['Utrain_branch'].shape) # Inputs to branch in training
print(data['Utest_branch'].shape) # Inputs to branch in testing
print(data['Vtest_out'].shape) # Output for test samples

# Convert NumPy arrays to PyTorch tensors
inputs_train = jnp.array(data['Utrain_branch']).T
outputs_train = jnp.array(data['Vtrain_out']).T
inputs_test = jnp.array(data['Utest_branch']).T
outputs_test = jnp.array(data['Vtest_out']).T
grid = jnp.array(data['Ytrain_trunk'])
#print("grid:", grid)

# Check the shapes of the subsets
print("Shape of inputs_train:", inputs_train.shape)
print("Shape of inputs_test:", inputs_test.shape)
print("Shape of outputs_train:", outputs_train.shape)
print("Shape of outputs_test:", outputs_test.shape)
print('#'*100)
# Out:
# (101, 935)
# (101, 249)
# (100, 249)
# Shape of inputs_train: (935, 101)
# Shape of inputs_test: (249, 101)
# Shape of outputs_train: (935, 100)
# Shape of outputs_test: (249, 100)
# ####################################################################################################

# %%
# Initialize the Glorot (Xavier) normal distribution for weight initialization
initializer = jax.nn.initializers.glorot_normal()

def init_glorot_params(layer_sizes, key = random.PRNGKey(seed)):
    """
    Initialize the parameters of the neural network using Glorot (Xavier) initialization.

    Args:
    layer_sizes (list): List of integers representing the size of each layer.
    key (PRNGKey): Random number generator key for reproducibility.

    Returns:
    list: List of tuples, each containing weights and biases for a layer.
    """
    return [(initializer(key, (m, n), jnp.float32), jnp.zeros(n))
            for m, n, in zip(layer_sizes[:-1], layer_sizes[1:])]

def BranchNet(params, x):
    """
    Implement the branch network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (array): Input to the branch network.

    Returns:
    array: Output of the branch network.
    """
    def single_forward(params, x):
        for w, b in params:
            outputs = jnp.dot(x, w) + b
            x = jnn.silu(outputs)
        return outputs

    return vmap(partial(single_forward, params))(x)

def TrunkNet(params, x):
    """
    Implement the trunk network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (float): First input to the trunk network.
    t (float): Second input to the trunk network.

    Returns:
    array: Output of the trunk network.
    """
    inputs = jnp.array(x)
    for w, b in params:
        outputs = jnp.dot(x, w) + b
        x = jnn.silu(outputs)
    return outputs

@jit
def DeepONet(params, branch_inputs, trunk_inputs):
    """
    Implement the complete DeepONet architecture.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.

    Returns:
    array: Output of the DeepONet.
    """
    params_branch, params_trunk = params
    branch_outputs = lambda x: BranchNet(params_branch, x)
    b_out = branch_outputs(branch_inputs)
    trunk_output = lambda y: TrunkNet(params_trunk, y)
    t_out = trunk_output(trunk_inputs)
    results = jnp.einsum('ik, lk -> il',b_out, t_out)
    return results

# network parameters.
p = 300 # Number of output neurons in both the branch and trunk net outputs.
nx = 101
input_neurons_branch = nx # m
input_neurons_trunk = 1

layer_sizes_b = [input_neurons_branch] + [100]*6 + [p]
layer_sizes_t = [input_neurons_trunk] + [100]*6 + [p]

params_branch = init_glorot_params(layer_sizes=layer_sizes_b)
params_trunk = init_glorot_params(layer_sizes=layer_sizes_t)

params= (params_branch, params_trunk)

def objective(params, branch_inputs, trunk_inputs, target_values):
    """
    Define the objective function (loss function) for training.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values to compare against.

    Returns:
    float: Mean squared error loss.
    """
    predictions = DeepONet(params, branch_inputs, trunk_inputs)
    loss_mse = jnp.mean((predictions - target_values)**2)
    return loss_mse


# Adam optimizer
@jit
def resnet_update(params, branch_input, trunk_inputs, target_values, opt_state):
    """
    Compute the gradient for a batch and update the parameters.

    Args:
    params (tuple): Current network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values.
    opt_state: Current state of the optimizer.

    Returns:
    tuple: Updated parameters, updated optimizer state, and current loss value.
    """
    value, grads = value_and_grad(objective)(params, branch_input, trunk_inputs, target_values)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, value

# Initialize the Adam optimizer
opt_init, opt_update, get_params = adam(step_size=1e-3, b1=0.9, b2=0.999, eps=1e-08)
opt_state = opt_init(params)

bs = 3000 #batch size
iteration_list, loss_list, test_loss_list = [], [], []
iteration = 0

n_epochs = 100000
num_samples = len(inputs_train)

# test input preparation
branch_inputs_test = inputs_test
targets = outputs_test

# %%
def save_model_params(params, resultdir, filename='model_params.pkl'):
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

    save_path = os.path.join(resultdir, filename)
    with open(save_path, 'wb') as f:
        pickle.dump(params, f)

def load_model_params(resultdir, filename='model_params.pkl'):
    load_path = os.path.join(resultdir, filename)
    with open(load_path, 'rb') as f:
        params = pickle.load(f)
    return params

# Saving
if save:
    save_model_params(params, resultdir)

# Loading (uncomment when needed)
# model_params = load_model_params(resultdir)

# %%
## Training of DeepONet
start = time.time() # start time of training
best_test_mse = float('inf')  # Initialize with infinity

# Save initial model at 0th iteration
save_model_params(params, resultdir, filename='model_params_best.pkl')
print("Saved initial model at iteration 0")

for iteration in range(n_epochs):
    indices = jax.random.permutation(jax.random.PRNGKey(0), num_samples)
    batch_index = indices[0:bs]
    inputs_train_shuffled = inputs_train[batch_index]
    outputs_train_shuffled = outputs_train[batch_index]
    target_values = outputs_train_shuffled
    branch_inputs = inputs_train_shuffled
    trunk_inputs = grid
    params, opt_state, value = resnet_update(params, branch_inputs, trunk_inputs, target_values, opt_state)

    if iteration % 1000 == 0:
        params_branch, params_trunk = params
        predictions = DeepONet(params, branch_inputs, trunk_inputs)
        test_mse = jnp.mean((predictions - target_values)**2)

        # Compare current test error with the best so far
        if test_mse < best_test_mse:
            best_test_mse = test_mse
            # Save the model as it's the best so far
            save_model_params(params, resultdir, filename='model_params_best.pkl')
            print(f"New best model saved at iteration {iteration} with test MSE: {test_mse:.7f}")

        finish = time.time() - start
        print(f"Iteration: {iteration:3d}, Train loss: {objective(params, branch_inputs, trunk_inputs, target_values):.7f}, Test loss: {test_mse:.7f}, Best test loss: {best_test_mse:.7f}, Time: {finish:.2f}")

    iteration_list.append(iteration)
    loss_list.append(objective(params, branch_inputs, trunk_inputs, target_values))
    test_loss_list.append(test_mse)

if save:
    np.save(os.path.join(resultdir, 'iteration_list.npy'), np.asarray(iteration_list))
    np.save(os.path.join(resultdir, 'loss_list.npy'), np.asarray(loss_list))
    np.save(os.path.join(resultdir, 'test_loss_list.npy'), np.asarray(test_loss_list))

# Plotting code remains the same
plt.figure()
plt.plot(iteration_list, loss_list, 'g', label='Training loss')
plt.plot(iteration_list, test_loss_list, '-b', label='Test loss')
plt.yscale("log")
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

if save:
    plt.savefig(os.path.join(resultdir, 'loss_plot.pdf'))

# end timer
finish = time.time() - start
print("Time (sec) to complete:\n" + str(finish))
# Out:
# Saved initial model at iteration 0
# New best model saved at iteration 0 with test MSE: 0.2616428
# Iteration:   0, Train loss: 0.2616428, Test loss: 0.2616428, Best test loss: 0.2616428, Time: 0.86
# New best model saved at iteration 1000 with test MSE: 0.0009836
# Iteration: 1000, Train loss: 0.0009836, Test loss: 0.0009836, Best test loss: 0.0009836, Time: 8.83
# New best model saved at iteration 2000 with test MSE: 0.0007914
# Iteration: 2000, Train loss: 0.0007914, Test loss: 0.0007914, Best test loss: 0.0007914, Time: 16.53
# New best model saved at iteration 3000 with test MSE: 0.0003727
# Iteration: 3000, Train loss: 0.0003727, Test loss: 0.0003727, Best test loss: 0.0003727, Time: 24.06
# New best model saved at iteration 4000 with test MSE: 0.0002312
# Iteration: 4000, Train loss: 0.0002312, Test loss: 0.0002312, Best test loss: 0.0002312, Time: 31.56
# New best model saved at iteration 5000 with test MSE: 0.0001371
# Iteration: 5000, Train loss: 0.0001371, Test loss: 0.0001371, Best test loss: 0.0001371, Time: 39.09
# New best model saved at iteration 6000 with test MSE: 0.0001196
# Iteration: 6000, Train loss: 0.0001196, Test loss: 0.0001196, Best test loss: 0.0001196, Time: 46.54
# Iteration: 7000, Train loss: 0.0002255, Test loss: 0.0002255, Best test loss: 0.0001196, Time: 53.97
# New best model saved at iteration 8000 with test MSE: 0.0001119
# Iteration: 8000, Train loss: 0.0001119, Test loss: 0.0001119, Best test loss: 0.0001119, Time: 61.51
# New best model saved at iteration 9000 with test MSE: 0.0001058
# Iteration: 9000, Train loss: 0.0001058, Test loss: 0.0001058, Best test loss: 0.0001058, Time: 69.09
# New best model saved at iteration 10000 with test MSE: 0.0000974
# Iteration: 10000, Train loss: 0.0000974, Test loss: 0.0000974, Best test loss: 0.0000974, Time: 76.88
# New best model saved at iteration 11000 with test MSE: 0.0000746
# Iteration: 11000, Train loss: 0.0000746, Test loss: 0.0000746, Best test loss: 0.0000746, Time: 84.87
# New best model saved at iteration 12000 with test MSE: 0.0000638
# Iteration: 12000, Train loss: 0.0000638, Test loss: 0.0000638, Best test loss: 0.0000638, Time: 92.55
# New best model saved at iteration 13000 with test MSE: 0.0000363
# Iteration: 13000, Train loss: 0.0000363, Test loss: 0.0000363, Best test loss: 0.0000363, Time: 100.18
# New best model saved at iteration 14000 with test MSE: 0.0000260
# Iteration: 14000, Train loss: 0.0000260, Test loss: 0.0000260, Best test loss: 0.0000260, Time: 107.76
# New best model saved at iteration 15000 with test MSE: 0.0000150
# Iteration: 15000, Train loss: 0.0000150, Test loss: 0.0000150, Best test loss: 0.0000150, Time: 115.38
# New best model saved at iteration 16000 with test MSE: 0.0000119
# Iteration: 16000, Train loss: 0.0000119, Test loss: 0.0000119, Best test loss: 0.0000119, Time: 122.94
# New best model saved at iteration 17000 with test MSE: 0.0000108
# Iteration: 17000, Train loss: 0.0000108, Test loss: 0.0000108, Best test loss: 0.0000108, Time: 130.56
# Iteration: 18000, Train loss: 0.0000404, Test loss: 0.0000404, Best test loss: 0.0000108, Time: 138.17
# New best model saved at iteration 19000 with test MSE: 0.0000102
# Iteration: 19000, Train loss: 0.0000102, Test loss: 0.0000102, Best test loss: 0.0000102, Time: 145.62
# Iteration: 20000, Train loss: 0.0000113, Test loss: 0.0000113, Best test loss: 0.0000102, Time: 153.15
# Iteration: 21000, Train loss: 0.0000132, Test loss: 0.0000132, Best test loss: 0.0000102, Time: 160.67
# New best model saved at iteration 22000 with test MSE: 0.0000073
# Iteration: 22000, Train loss: 0.0000073, Test loss: 0.0000073, Best test loss: 0.0000073, Time: 168.17
# Iteration: 23000, Train loss: 0.0000650, Test loss: 0.0000650, Best test loss: 0.0000073, Time: 176.05
# Iteration: 24000, Train loss: 0.0000219, Test loss: 0.0000219, Best test loss: 0.0000073, Time: 183.71
# Iteration: 25000, Train loss: 0.0000135, Test loss: 0.0000135, Best test loss: 0.0000073, Time: 191.55
# Iteration: 26000, Train loss: 0.0000145, Test loss: 0.0000145, Best test loss: 0.0000073, Time: 199.15
# New best model saved at iteration 27000 with test MSE: 0.0000072
# Iteration: 27000, Train loss: 0.0000072, Test loss: 0.0000072, Best test loss: 0.0000072, Time: 206.76
# Iteration: 28000, Train loss: 0.0000077, Test loss: 0.0000077, Best test loss: 0.0000072, Time: 214.34
# Iteration: 29000, Train loss: 0.0000243, Test loss: 0.0000243, Best test loss: 0.0000072, Time: 221.90
# Iteration: 30000, Train loss: 0.0000180, Test loss: 0.0000180, Best test loss: 0.0000072, Time: 229.41
# Iteration: 31000, Train loss: 0.0000074, Test loss: 0.0000074, Best test loss: 0.0000072, Time: 237.03
# New best model saved at iteration 32000 with test MSE: 0.0000068
# Iteration: 32000, Train loss: 0.0000068, Test loss: 0.0000068, Best test loss: 0.0000068, Time: 244.50
# Iteration: 33000, Train loss: 0.0000156, Test loss: 0.0000156, Best test loss: 0.0000068, Time: 252.09
# Iteration: 34000, Train loss: 0.0000071, Test loss: 0.0000071, Best test loss: 0.0000068, Time: 259.60
# Iteration: 35000, Train loss: 0.0000072, Test loss: 0.0000072, Best test loss: 0.0000068, Time: 267.18
# Iteration: 36000, Train loss: 0.0000439, Test loss: 0.0000439, Best test loss: 0.0000068, Time: 274.67
# New best model saved at iteration 37000 with test MSE: 0.0000056
# Iteration: 37000, Train loss: 0.0000056, Test loss: 0.0000056, Best test loss: 0.0000056, Time: 282.32
# New best model saved at iteration 38000 with test MSE: 0.0000052
# Iteration: 38000, Train loss: 0.0000052, Test loss: 0.0000052, Best test loss: 0.0000052, Time: 289.80
# New best model saved at iteration 39000 with test MSE: 0.0000017
# Iteration: 39000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000017, Time: 297.30
# Iteration: 40000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000017, Time: 304.91
# Iteration: 41000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000017, Time: 312.47
# Iteration: 42000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000017, Time: 320.01
# Iteration: 43000, Train loss: 0.0000029, Test loss: 0.0000029, Best test loss: 0.0000017, Time: 327.55
# Iteration: 44000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000017, Time: 335.06
# Iteration: 45000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000017, Time: 342.64
# Iteration: 46000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000017, Time: 350.17
# Iteration: 47000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000017, Time: 357.75
# Iteration: 48000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000017, Time: 365.28
# Iteration: 49000, Train loss: 0.0000091, Test loss: 0.0000091, Best test loss: 0.0000017, Time: 372.87
# Iteration: 50000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000017, Time: 380.46
# New best model saved at iteration 51000 with test MSE: 0.0000011
# Iteration: 51000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000011, Time: 388.28
# Iteration: 52000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000011, Time: 395.85
# Iteration: 53000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000011, Time: 403.47
# Iteration: 54000, Train loss: 0.0000163, Test loss: 0.0000163, Best test loss: 0.0000011, Time: 411.00
# Iteration: 55000, Train loss: 0.0000107, Test loss: 0.0000107, Best test loss: 0.0000011, Time: 418.51
# Iteration: 56000, Train loss: 0.0000103, Test loss: 0.0000103, Best test loss: 0.0000011, Time: 426.08
# New best model saved at iteration 57000 with test MSE: 0.0000010
# Iteration: 57000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000010, Time: 433.55
# Iteration: 58000, Train loss: 0.0000061, Test loss: 0.0000061, Best test loss: 0.0000010, Time: 441.10
# Iteration: 59000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000010, Time: 448.68
# New best model saved at iteration 60000 with test MSE: 0.0000010
# Iteration: 60000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000010, Time: 456.39
# New best model saved at iteration 61000 with test MSE: 0.0000008
# Iteration: 61000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 464.02
# Iteration: 62000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 471.79
# Iteration: 63000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000008, Time: 479.46
# Iteration: 64000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000008, Time: 487.10
# Iteration: 65000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 494.72
# Iteration: 66000, Train loss: 0.0000100, Test loss: 0.0000100, Best test loss: 0.0000008, Time: 502.37
# Iteration: 67000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000008, Time: 510.08
# Iteration: 68000, Train loss: 0.0000516, Test loss: 0.0000516, Best test loss: 0.0000008, Time: 518.09
# Iteration: 69000, Train loss: 0.0000143, Test loss: 0.0000143, Best test loss: 0.0000008, Time: 526.38
# Iteration: 70000, Train loss: 0.0000079, Test loss: 0.0000079, Best test loss: 0.0000008, Time: 535.45
# Iteration: 71000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000008, Time: 544.79
# Iteration: 72000, Train loss: 0.0000035, Test loss: 0.0000035, Best test loss: 0.0000008, Time: 554.28
# Iteration: 73000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000008, Time: 564.88
# Iteration: 74000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000008, Time: 576.04
# Iteration: 75000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000008, Time: 587.67
# Iteration: 76000, Train loss: 0.0000138, Test loss: 0.0000138, Best test loss: 0.0000008, Time: 599.12
# Iteration: 77000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000008, Time: 609.91
# Iteration: 78000, Train loss: 0.0000090, Test loss: 0.0000090, Best test loss: 0.0000008, Time: 619.94
# Iteration: 79000, Train loss: 0.0000175, Test loss: 0.0000175, Best test loss: 0.0000008, Time: 629.25
# Iteration: 80000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000008, Time: 638.03
# New best model saved at iteration 81000 with test MSE: 0.0000006
# Iteration: 81000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000006, Time: 646.43
# Iteration: 82000, Train loss: 0.0000097, Test loss: 0.0000097, Best test loss: 0.0000006, Time: 654.69
# New best model saved at iteration 83000 with test MSE: 0.0000004
# Iteration: 83000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 662.73
# Iteration: 84000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000004, Time: 670.69
# Iteration: 85000, Train loss: 0.0000045, Test loss: 0.0000045, Best test loss: 0.0000004, Time: 678.51
# Iteration: 86000, Train loss: 0.0000063, Test loss: 0.0000063, Best test loss: 0.0000004, Time: 686.29
# Iteration: 87000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 693.94
# Iteration: 88000, Train loss: 0.0000079, Test loss: 0.0000079, Best test loss: 0.0000004, Time: 701.54
# New best model saved at iteration 89000 with test MSE: 0.0000004
# Iteration: 89000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 709.15
# Iteration: 90000, Train loss: 0.0000044, Test loss: 0.0000044, Best test loss: 0.0000004, Time: 716.72
# Iteration: 91000, Train loss: 0.0000058, Test loss: 0.0000058, Best test loss: 0.0000004, Time: 724.30
# Iteration: 92000, Train loss: 0.0000090, Test loss: 0.0000090, Best test loss: 0.0000004, Time: 731.82
# Iteration: 93000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000004, Time: 739.31
# Iteration: 94000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000004, Time: 746.92
# Iteration: 95000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000004, Time: 754.40
# Iteration: 96000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000004, Time: 761.92
# Iteration: 97000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000004, Time: 769.43
# New best model saved at iteration 98000 with test MSE: 0.0000003
# Iteration: 98000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000003, Time: 776.98
# Iteration: 99000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000003, Time: 784.51
# Time (sec) to complete:
# 793.2975850105286

# %%
# params_branch, params_trunk = params
# Load the best model parameters
best_params = load_model_params(resultdir, filename='model_params_best.pkl')
print("Loaded best model parameters")

# Predictions
mse_list = []

branch_inputs = inputs_test
trunk_inputs = grid
prediction = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval) 

save_dict = {'u_test': inputs_test.T, 'v_pred': prediction.T,\
             'v_target': outputs_test.T}

io.savemat(resultdir+'/pred.mat', save_dict)

for i in range(inputs_test.shape[0]):

    branch_inputs = inputs_test[i].reshape(1, nx) 
    trunk_inputs = grid # (neval, 1) 

    prediction_i = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval)
    target_i = outputs_test[i]

    mse_i = np.mean((prediction_i - target_i)**2)
    mse_list.append(mse_i.item())

    if i % 100 == 0:
        print(colored('TEST SAMPLE '+str(i+1), 'red'))

        r2score = metrics.r2_score(target_i.flatten(), prediction_i.flatten())
        relerror = np.linalg.norm(target_i- prediction_i) / np.linalg.norm(target_i)
        r2score = float('%.4f'%r2score)
        relerror = float('%.4f'%relerror)
        print('Rel. L2 Error = '+str(relerror)+', R2 score = '+str(r2score))

        fig = plt.figure(figsize=(15, 4))

        # Adjust subplot parameters for better spacing
        plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.3)

        # Input plot
        ax = fig.add_subplot(1, 3, 1)
        plt.plot(inputs_test[i,0:-1])
        plt.title('Input', fontsize=14)

        # Output plot
        ax = fig.add_subplot(1, 3, 2)
        target = target_i.reshape(grid.shape[0])
        prediction = prediction_i.reshape(grid.shape[0])
        plt.plot(target, color='blue', linewidth=2)
        plt.plot(prediction, color='red', linewidth=2)
        plt.title('Output Field', fontsize=14)
        plt.legend(['Target', 'Prediction'])

        # Error plot
        ax = fig.add_subplot(1, 3, 3)
        error = target - prediction
        plt.plot(error, color='magenta')
        # plt.yscale("log")  
        plt.title('Absolute Error', fontsize=14)

        print(colored('#'*230, 'green'))

mse = sum(mse_list) / len(mse_list)
print("Mean Squared Error Test :\n", mse)
# Out:
# Loaded best model parameters
# TEST SAMPLE 1
# Rel. L2 Error = 0.0016, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 101
# Rel. L2 Error = 0.0014, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 201
# Rel. L2 Error = 0.0011, R2 score = 1.0
# ######################################################################################################################################################################################################################################
# Mean Squared Error Test :
#  3.6841204134373703e-07
